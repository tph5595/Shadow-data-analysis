# %%
import yaml
import pickle

for s in range(30):
    config_file = f"../config_multiscope/podns_multi_scale5k10k_base_100_{s+1}.yaml"
    
    with open(config_file, 'r') as file:
        config = yaml.safe_load(file)
    
    
    
    
    p_filename = "../" + config['experiment_name'] + "_ts.pkl"
    
    with open(p_filename, 'rb') as file:
        src = pickle.load(file)
        dst = pickle.load(file)
    print(f"{len(src)}\t{len(dst)}")
# Out:
# 93	98
# 96	98
# 92	98
# 95	98
# 98	98
# 88	98
# 94	98
# 93	98
# 91	98
# 94	98
# 90	98
# 95	98
# 93	98
# 95	98
# 91	98
# 92	98
# 96	98
# 95	98
# 93	98
# 94	98
# 92	98
# 93	98
# 94	98
# 96	98
# 92	98
# 92	98
# 92	98
# 90	98
# 92	98
# 95	98

# %%
len(src)
# Out:
# 93

# %%
len(dst)
# Out:
# 98
