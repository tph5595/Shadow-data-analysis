# %%
! pip install pandas matplotlib
# Knapsack NP complete could work
# or check for candidate DNSers that would be apart of the resource access and with enough resource access and DNS 
# could probably determine\


# What if determine candicate from DNSers like above but then look at their input to tor (frame size and timing 
# input and output with TDA to filter down candidates)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/taylor/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: matplotlib in /home/taylor/.local/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/taylor/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/taylor/.local/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Get argus flows from PCAPs
# !../util/process_data_argus.sh
# Out:
# ra[465682]: 14:37:55.664226 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465696]: 14:37:57.694447 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465708]: 14:37:59.746106 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465714]: 14:38:00.754367 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[465735]: 14:38:01.765699 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465757]: 14:38:02.774425 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[465768]: 14:38:03.786942 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465789]: 14:38:06.813164 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 465795 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[465808]: 14:38:09.933395 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465815]: 14:38:10.942476 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 465821 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[465833]: 14:38:14.050346 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465839]: 14:38:15.060001 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[465845]: 14:38:16.073054 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 465853 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[465864]: 14:38:19.170084 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465870]: 14:38:20.178748 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[465876]: 14:38:21.190637 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 465882 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[465893]: 14:38:24.285803 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 465899 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[465942]: 14:38:27.382485 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465951]: 14:38:28.390707 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[465964]: 14:38:29.402804 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465984]: 14:38:30.412848 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[465990]: 14:38:31.425196 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[465999]: 14:38:32.437887 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 466005 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[466024]: 14:38:35.535248 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466030]: 14:38:36.547538 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466036]: 14:38:37.569265 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466042]: 14:38:38.580340 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466049]: 14:38:39.593767 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466055]: 14:38:40.603258 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466061]: 14:38:41.615603 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466067]: 14:38:42.625071 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466076]: 14:38:43.638511 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466082]: 14:38:44.647421 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466090]: 14:38:45.658321 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466098]: 14:38:46.667053 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466104]: 14:38:47.675682 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466110]: 14:38:48.687815 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466117]: 14:38:49.696189 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466123]: 14:38:50.705948 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466129]: 14:38:51.714346 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466135]: 14:38:52.726379 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466141]: 14:38:53.740266 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466147]: 14:38:54.752817 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466153]: 14:38:55.765346 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466159]: 14:38:56.774281 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466167]: 14:38:57.787579 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[466173]: 14:38:58.796553 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 466196 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[466212]: 14:39:03.909395 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466220]: 14:39:04.947003 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 466226 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ../util/process_data_argus.sh: line 3: 466238 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[466250]: 14:39:10.137491 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 466256 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[466267]: 14:39:13.228086 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[466273]: 14:39:14.238476 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 466279 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ../util/process_data_argus.sh: line 3: 466290 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[466301]: 14:39:19.418090 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 466309 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ../util/process_data_argus.sh: line 3: 466319 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# mkdir: cannot create directory ‘data/argus’: File exists
# mkdir: cannot create directory ‘data/argus/csv’: File exists

# %%
# PCAP to CSV
# !../util/pcap_to_csv.sh
# Out:
# mkdir: cannot create directory ‘data/csv’: File exists

# %%
# PCAPNG to CSV
# !../util/pcapng_to_csv.sh
# Out:
# mkdir: cannot create directory ‘data/csv’: File exists

# %%
from os import listdir
from os.path import isfile, join

def getFilenames(path):
    return [path+f for f in listdir(path) if isfile(join(path, f))]

# %%
# Get argus data
arguspath = "data/argus/csv/"
argusCSVs = getFilenames(arguspath)

# Get pcap data
pcappath = "data/csv/"
pcapCSVs = getFilenames(pcappath)
data = argusCSVs + pcapCSVs

# %%
import pandas as pd

# %%
df = pd.read_csv (pcapCSVs[0])
df
# Out:
#        frame.number                           frame.time     ip.src  \
# 0                 1  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 1                 2  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 2                 3  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 3                 4  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 4                 5  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# ...             ...                                  ...        ...
# 44267         44268  Dec 31, 1969 21:59:58.168010000 EST  127.0.0.1
# 44268         44269  Dec 31, 1969 21:59:59.163010000 EST  127.0.0.1
# 44269         44270  Dec 31, 1969 21:59:59.163010000 EST  127.0.0.1
# 44270         44271  Dec 31, 1969 21:59:59.168010000 EST  127.0.0.1
# 44271         44272  Dec 31, 1969 21:59:59.168010000 EST  127.0.0.1
#
#           ip.dst  ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  \
# 0      127.0.0.1         6         40      40            1            0
# 1      127.0.0.1         6         40      40            1            0
# 2      127.0.0.1         6         40      40            1            0
# 3      127.0.0.1         6         40      40            1            0
# 4      127.0.0.1         6         65      65            1            0
# ...          ...       ...        ...     ...          ...          ...
# 44267  127.0.0.1         6         40      40            1            0
# 44268  127.0.0.1         6         53      53            1            0
# 44269  127.0.0.1         6         53      53            1            0
# 44270  127.0.0.1         6         40      40            1            0
# 44271  127.0.0.1         6         40      40            1            0
#
#        ip.fragment  ...  dtls.handshake.extensions_alpn_str_len  \
# 0              NaN  ...                                     NaN
# 1              NaN  ...                                     NaN
# 2              NaN  ...                                     NaN
# 3              NaN  ...                                     NaN
# 4              NaN  ...                                     NaN
# ...            ...  ...                                     ...
# 44267          NaN  ...                                     NaN
# 44268          NaN  ...                                     NaN
# 44269          NaN  ...                                     NaN
# 44270          NaN  ...                                     NaN
# 44271          NaN  ...                                     NaN
#
#        dtls.handshake.extensions_key_share_client_length  http.request  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44267                                                NaN           NaN
# 44268                                                NaN           NaN
# 44269                                                NaN           NaN
# 44270                                                NaN           NaN
# 44271                                                NaN           NaN
#
#        udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
# 0           NaN              0.00000             0.000            0.00000
# 1           NaN              0.00000             0.000            0.00000
# 2           NaN              0.00000             0.000            0.00000
# 3           NaN              0.00000             0.000            0.00000
# 4           NaN              0.00000             0.000            0.00000
# ...         ...                  ...               ...                ...
# 44267       NaN          10557.16801             0.000        10557.16801
# 44268       NaN          10558.16301             0.995        10558.16301
# 44269       NaN          10558.16301             0.000        10558.16301
# 44270       NaN          10558.16801             0.005        10558.16801
# 44271       NaN          10558.16801             0.000        10558.16801
#
#        tcp.time_delta                                        tcp.payload  \
# 0               0.000                                                NaN
# 1               0.000                                                NaN
# 2               0.000                                                NaN
# 3               0.000                                                NaN
# 4               0.000  41555448454e544943415445202270617373776f726422...
# ...               ...                                                ...
# 44267           0.000                                                NaN
# 44268           0.995                         36353020425720302031330d0a
# 44269           0.000                         36353020425720302031330d0a
# 44270           0.005                                                NaN
# 44271           0.000                                                NaN
#
#       dns.qry.name
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 44267          NaN
# 44268          NaN
# 44269          NaN
# 44270          NaN
# 44271          NaN
#
# [44272 rows x 59 columns]

# %%
len(data)
# Out:
# 148

# %%
len(argusCSVs)
# Out:
# 74

# %%
# Basic Scopes
import re

# Get all clients and ISP dns scope
r = re.compile(".*isp.csv|.*Client[0-9]*-(?!127\.0\.0\.1)[0-9]*.[0-9]*.[0-9]*.[0-9]*..csv")
ISP_scope = list(filter(r.match, data))

# Access to public resolver scope
r = re.compile(".*isp.csv")
Access_resolver = list(filter(r.match, data))

# DNS Scope
r = re.compile("(.*tld|.*root-server|.*sld).csv")
Access_to_auth_zone = list(filter(r.match, data))

# Access Tor Scope
r = re.compile(".*Client[0-9]*-(?!127\.0\.0\.1)[0-9]*.[0-9]*.[0-9]*.[0-9]*..csv")
Access_tor = list(filter(r.match, data))

# Server Public Scope
r = re.compile(".*myMarkovServer0*-(?!127\.0\.0\.1)[0-9]*\.[0-9]*\.[0-9]*\.[0-9]*.csv")
Server_scope = list(filter(r.match, data))

# tor Exit scope
r = re.compile(".*exit.*")
Tor_exit_Scope = list(filter(r.match, data))

# tor Guard scope
r = re.compile(".*guard.*")
Tor_guard_Scope = list(filter(r.match, data))

# tor Relay scope
r = re.compile(".*relay.*")
Tor_relay_Scope = list(filter(r.match, data))

# tor Middle scope
r = re.compile(".*middle.*")
Tor_middle_Scope = list(filter(r.match, data))

# tor 4uthority scope
r = re.compile(".*4uthority.*")
Tor_4uthority_Scope = list(filter(r.match, data))

# resolver scope
r = re.compile(".*resolver.*")
resolver_Scope = list(filter(r.match, data))

# %%
def pcap_only(lis):
    r = re.compile(".*data/csv.*")
    return list(filter(r.match, lis))

def format_time_col(df, time_col):
    time_format='%b %d, %Y %X.%f'
    df[time_col] = df[time_col].apply(lambda x: datetime.strptime(x[:-7], time_format))
    df.set_index(time_col)
    return df

def scope_to_df(scope):
    df = pd.DataFrame()
    for f in scope:
        ddf = pd.read_csv (f)
        df = pd.concat([df, ddf])
    return df

# %%
from datetime import datetime

def df_to_ts(df):
    df['count'] = 1
    #  Minute is T
    return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()

# %%
# get start time for GNS3
GNS3_data = format_time_col(scope_to_df(pcap_only(Access_resolver + Access_to_auth_zone)), 'frame.time')
GNS3_starttime = GNS3_data.head(1)['frame.time'].tolist()[0]
Shadow_starttime = datetime.strptime('Dec 31, 1969 19:30:00', '%b %d, %Y %X')
Shadow_offset = GNS3_starttime - Shadow_starttime
Shadow_offset
# Out:
# Timedelta('19439 days 19:16:52.826347')

# %%
dns_df = format_time_col(scope_to_df(pcap_only(Access_to_auth_zone)), 'frame.time')

# %%
# Steps
# Who do this
# Cluster of who this
# Cluster per scope? all scopes?
# Link Clusters

# %%
# Assume range is whole experiment
# Justification: Looking for first group and all groups at same time (30 minute range, In future should have comms
# going on that start before we are looking [noise])

# %%
window = pd.Timedelta("300 seconds") # cache size but maybe smaller 

# detect and remove solo quries
# these can easily be handled on their own as only 1 device is accessing the network at that moment
def detect_solo(df_list):
    new_df = df_list[df_list['ip.src'].ne(df_list['ip.src'].shift())]
    new_df['diff'] = new_df['frame.time'].diff()
    new_df = new_df[new_df['diff'] > window]
    solo_ips = new_df['ip.src'].unique()
    return solo_ips

def handle_solo(solo):
    print("IPs that must trigger a cache miss: ")
    print(solo)
    
def solo_pipeline(df_list):
    fil = df_list[['ip.src', 'frame.time']]
    solo = detect_solo(fil)
    handle_solo(solo)
    return solo

# %%
# Cluster DNS
## Create ts for each IP
resolv_df = format_time_col(scope_to_df(pcap_only(resolver_Scope)), 'frame.time')
DNS_PROTO = 17.0
resolv_df_filtered = resolv_df[resolv_df['ip.proto'] == DNS_PROTO]
IPs = resolv_df_filtered['ip.src'].unique()
flows_ip = {}
flows_ts_ip = {}
infra_ip = ['172.20.0.11', '172.20.0.12', '192.168.150.10']
evil_domain = 'evil.dne'
first_pass = resolv_df_filtered[((~resolv_df_filtered['ip.src'].isin(infra_ip)))  \
                                         & (resolv_df_filtered['dns.qry.name'] == evil_domain)]
solo = solo_pipeline(first_pass)
for ip in IPs:
    if ip not in infra_ip and ip not in solo:
        flows_ip[ip] = first_pass[((first_pass['ip.dst'] == ip) | \
                                   (first_pass['ip.src'] == ip))]
        temp = df_to_ts(flows_ip[ip].copy()).set_index('frame.time')
        if len(temp) > 0:
            flows_ts_ip[ip] = temp
# Out:
# IPs that must trigger a cache miss:
# ['102.0.0.2' '102.0.0.8' '102.0.0.5' '102.0.0.22']
# /tmp/ipykernel_378350/4224260682.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['diff'] = new_df['frame.time'].diff()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()

# %%
flows_ip[ip]['dns.qry.name'].unique()
# Out:
# array(['evil.dne'], dtype=object)

# %%
flows_ts_ip[ip]['count']
# Out:
# frame.time
# 2023-03-23 14:49:39     2.0
# 2023-03-23 14:49:40     0.0
# 2023-03-23 14:49:41     0.0
# 2023-03-23 14:49:42     0.0
# 2023-03-23 14:49:43     0.0
# 2023-03-23 14:49:44     2.0
# 2023-03-23 14:49:45     2.0
# 2023-03-23 14:49:46     4.0
# 2023-03-23 14:49:47     4.0
# 2023-03-23 14:49:48     4.0
# 2023-03-23 14:49:49     4.0
# 2023-03-23 14:49:50     4.0
# 2023-03-23 14:49:51     4.0
# 2023-03-23 14:49:52     4.0
# 2023-03-23 14:49:53     4.0
# 2023-03-23 14:49:54     2.0
# 2023-03-23 14:49:55     2.0
# 2023-03-23 14:49:56     0.0
# 2023-03-23 14:49:57     0.0
# 2023-03-23 14:49:58     0.0
# 2023-03-23 14:49:59     0.0
# 2023-03-23 14:50:00     0.0
# 2023-03-23 14:50:01     0.0
# 2023-03-23 14:50:02     0.0
# 2023-03-23 14:50:03     0.0
# 2023-03-23 14:50:04     0.0
# 2023-03-23 14:50:05     0.0
# 2023-03-23 14:50:06     0.0
# 2023-03-23 14:50:07     0.0
# 2023-03-23 14:50:08     0.0
# 2023-03-23 14:50:09     0.0
# 2023-03-23 14:50:10     0.0
# 2023-03-23 14:50:11     0.0
# 2023-03-23 14:50:12     0.0
# 2023-03-23 14:50:13     0.0
# 2023-03-23 14:50:14     0.0
# 2023-03-23 14:50:15     0.0
# 2023-03-23 14:50:16     0.0
# 2023-03-23 14:50:17     0.0
# 2023-03-23 14:50:18     0.0
# 2023-03-23 14:50:19     0.0
# 2023-03-23 14:50:20     0.0
# 2023-03-23 14:50:21     0.0
# 2023-03-23 14:50:22     0.0
# 2023-03-23 14:50:23     0.0
# 2023-03-23 14:50:24     0.0
# 2023-03-23 14:50:25     0.0
# 2023-03-23 14:50:26     0.0
# 2023-03-23 14:50:27     0.0
# 2023-03-23 14:50:28     0.0
# 2023-03-23 14:50:29     0.0
# 2023-03-23 14:50:30     0.0
# 2023-03-23 14:50:31     2.0
# 2023-03-23 14:50:32     4.0
# 2023-03-23 14:50:33     6.0
# 2023-03-23 14:50:34    10.0
# Name: count, dtype: float64

# %%
## Viz
# importing Libraries
  
# import pandas as pd
import pandas as pd
  
# importing matplotlib module
import matplotlib.pyplot as plt
plt.style.use('default')
  
# %matplotlib inline: only draw static
# images in the notebook
# %matplotlib inline

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

for f in flows_ts_ip:
    flows_ts_ip[f]['count'].plot(label=f)
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
plt.ylabel('Requests (seconds)')
  
# adding legend to the curve
plt.legend()

# %%
# !pip install scikit-learn
from sklearn.cluster import KMeans
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/taylor/.local/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.10.1)

# %%
def generate_features(df, flow):
    features = []
    # 'first_seen'
    features += [float(df['frame.time'].min().timestamp())]
    # 'last_seen'
    features += [float(df['frame.time'].max().timestamp())]
    # 'reqs_per_sec'
    features += [flow['count'].mean()]
    # 'reqs_per_sec_std'
    val = flow['count'].std()
    features += [0 if np.isnan(val) else val]
    # 'total_req'
    features += [len(df)]
    # 'reqs_max'
    features += [flow['count'].max()]
    # 'reqs_min'
    features += [flow['count'].min()]
    return [features]
## Get flow features
def all_features(df, flow, bad):
    df = df.drop(columns=bad)
    df_mean = df.median(numeric_only=True).add_suffix('_mean').to_frame().transpose()
    df_min = df.min(numeric_only=True).add_suffix('_min').to_frame().transpose()
    df_max = df.max(numeric_only=True).add_suffix('_max').to_frame().transpose()
    df_range = df.max(numeric_only=True) - df.min(numeric_only=True)
    df_range = df_range.add_suffix('_range').to_frame().transpose()
    df_std = df.std(numeric_only=True).add_suffix('_std').to_frame().transpose()
    
    flow = flow.drop(columns=bad)
    ts_mean = flow.mean(numeric_only=True).add_suffix('_mean_ts').to_frame().transpose()
    ts_min = flow.min(numeric_only=True).add_suffix('_min_ts').to_frame().transpose()
    ts_max = flow.max(numeric_only=True).add_suffix('_max_ts').to_frame().transpose()
    ts_range = flow.max(numeric_only=True) - flow.min(numeric_only=True)
    ts_range = ts_range.add_suffix('_range_ts').to_frame().transpose()
    ts_std = flow.std(numeric_only=True).add_suffix('_std_ts').to_frame().transpose()
    
    return pd.concat([df_mean, df_min, df_max, df_std, df_range, ts_mean, ts_min, ts_max, ts_std, ts_range], axis=1)
cols = ['first_seen','last_seen', 'reqs_per_sec', 'reqs_per_sec_std', 'total_req', 'reqs_max', 'reqs_min']
index = []
feature_data = []
all_f = pd.DataFrame()
bad_features = ['udp.port', 'frame.number']
for ip in flows_ts_ip:
    index += [ip]
    feature_data += generate_features(flows_ip[ip], flows_ts_ip[ip])
    all_tmp = all_features(flows_ip[ip], flows_ts_ip[ip], bad_features)
    all_tmp.index = [ip]
    all_f = pd.concat([all_f, all_tmp], axis=0)

    # drop col if all na
all_f = all_f.dropna(axis=1, how='all')
# drop col if all same value
nunique = all_f.nunique()
cols_to_drop = nunique[nunique == 1].index
all_f = all_f.drop(cols_to_drop, axis=1)

# Create the pandas DataFrame
df_old = pd.DataFrame(feature_data, columns=cols, index=index)
df = all_f
df
# Out:
#             frame.time_relative_mean  frame.time_delta_mean  \
# 102.0.0.4                  79.340570               0.020008
# 102.0.0.6                  76.392925               0.000106
# 102.0.0.7                 136.907950               0.000091
# 102.0.0.9                  88.123756               0.004898
# 102.0.0.10                 77.871116               0.020324
# 102.0.0.12                141.508597               0.000102
# 102.0.0.11                 98.218042               0.030309
# 102.0.0.3                 267.130680               0.009872
# 102.0.0.13                167.238192               0.004831
# 102.0.0.18                131.821713               0.004868
# 102.0.0.17                148.874666               0.000091
# 102.0.0.21                133.028215               0.003899
# 102.0.0.15                149.139139               0.005165
# 102.0.0.24                135.985297               0.009583
# 102.0.0.19                149.281588               0.003581
# 102.0.0.25                153.397586               0.004809
# 102.0.0.23                148.317421               0.004964
# 102.0.0.16                160.862627               0.000077
# 102.0.0.20                179.526357               0.000082
# 102.0.0.14                155.851247               0.000100
# 102.0.0.26                218.790318               0.014805
#
#             frame.time_relative_min  frame.time_delta_min  \
# 102.0.0.4                 60.431418              0.000024
# 102.0.0.6                 64.652442              0.000018
# 102.0.0.7                 74.397351              0.000020
# 102.0.0.9                 74.600939              0.000054
# 102.0.0.10                77.097061              0.000067
# 102.0.0.12                95.628411              0.000018
# 102.0.0.11                96.918547              0.000051
# 102.0.0.3                236.577613              0.000052
# 102.0.0.13               115.561874              0.000050
# 102.0.0.18               117.529933              0.000051
# 102.0.0.17               119.976473              0.000019
# 102.0.0.21               121.954838              0.000039
# 102.0.0.15               127.406765              0.000053
# 102.0.0.24               134.270946              0.000043
# 102.0.0.19               136.117317              0.000050
# 102.0.0.25               136.633989              0.000051
# 102.0.0.23               141.610551              0.000063
# 102.0.0.16               146.105561              0.000021
# 102.0.0.20               161.441251              0.000019
# 102.0.0.14               153.330965              0.000024
# 102.0.0.26               157.196715              0.000075
#
#             frame.time_relative_max  frame.time_delta_max  \
# 102.0.0.4                225.080654              0.829733
# 102.0.0.6                307.707203              4.015252
# 102.0.0.7                163.674241              1.205633
# 102.0.0.9                110.435901              0.739741
# 102.0.0.10               113.727689              0.971113
# 102.0.0.12               189.072222              1.123890
# 102.0.0.11               124.364728              0.353554
# 102.0.0.3                313.794522              0.828996
# 102.0.0.13               235.006564              2.326523
# 102.0.0.18               167.756093              0.869701
# 102.0.0.17               207.278323              0.819925
# 102.0.0.21               200.471486              0.607858
# 102.0.0.15               158.669305              0.587192
# 102.0.0.24               146.319943              0.475253
# 102.0.0.19               235.917923              1.082203
# 102.0.0.25               158.740373              0.242929
# 102.0.0.23               164.110702              0.495508
# 102.0.0.16               175.197006              0.385185
# 102.0.0.20               190.979186              0.780246
# 102.0.0.14               173.966677              0.243064
# 102.0.0.26               221.932604              1.264436
#
#             frame.time_relative_std  frame.time_delta_std  \
# 102.0.0.4                 42.506464              0.194304
# 102.0.0.6                 64.105664              0.729618
# 102.0.0.7                 31.277843              0.157725
# 102.0.0.9                  9.987603              0.140846
# 102.0.0.10                13.083803              0.261288
# 102.0.0.12                30.560534              0.190375
# 102.0.0.11                11.598609              0.121172
# 102.0.0.3                 20.219969              0.240007
# 102.0.0.13                28.357990              0.401735
# 102.0.0.18                12.131172              0.184766
# 102.0.0.17                20.708754              0.173075
# 102.0.0.21                30.564028              0.155146
# 102.0.0.15                13.454991              0.158243
# 102.0.0.24                 5.292022              0.127413
# 102.0.0.19                19.948694              0.230775
# 102.0.0.25                 6.395649              0.067785
# 102.0.0.23                 8.443491              0.145717
# 102.0.0.16                 7.735121              0.098985
# 102.0.0.20                10.686034              0.200992
# 102.0.0.14                 8.612365              0.069695
# 102.0.0.26                26.885436              0.336345
#
#             frame.time_relative_range  frame.time_delta_range  ...  \
# 102.0.0.4                  164.649236                0.829709  ...
# 102.0.0.6                  243.054761                4.015234  ...
# 102.0.0.7                   89.276890                1.205613  ...
# 102.0.0.9                   35.834962                0.739687  ...
# 102.0.0.10                  36.630628                0.971046  ...
# 102.0.0.12                  93.443811                1.123872  ...
# 102.0.0.11                  27.446181                0.353503  ...
# 102.0.0.3                   77.216909                0.828944  ...
# 102.0.0.13                 119.444690                2.326473  ...
# 102.0.0.18                  50.226160                0.869650  ...
# 102.0.0.17                  87.301850                0.819906  ...
# 102.0.0.21                  78.516648                0.607819  ...
# 102.0.0.15                  31.262540                0.587139  ...
# 102.0.0.24                  12.048997                0.475210  ...
# 102.0.0.19                  99.800606                1.082153  ...
# 102.0.0.25                  22.106384                0.242878  ...
# 102.0.0.23                  22.500151                0.495445  ...
# 102.0.0.16                  29.091445                0.385164  ...
# 102.0.0.20                  29.537935                0.780227  ...
# 102.0.0.14                  20.635712                0.243040  ...
# 102.0.0.26                  64.735889                1.264361  ...
#
#             frame.time_delta_std_ts  count_std_ts  ip.proto_range_ts  \
# 102.0.0.4                  0.571538      4.357503              340.0
# 102.0.0.6                  0.594987      3.861260              374.0
# 102.0.0.7                  1.343979     17.310277              850.0
# 102.0.0.9                  0.745914      6.565502              408.0
# 102.0.0.10                 0.302630      2.376027              204.0
# 102.0.0.12                 1.295951     11.085540              816.0
# 102.0.0.11                 0.232707      2.820974              170.0
# 102.0.0.3                  1.252088      6.639801              374.0
# 102.0.0.13                 0.935309      5.867230              340.0
# 102.0.0.18                 0.960159      7.676381              408.0
# 102.0.0.17                 0.422188      5.145592              272.0
# 102.0.0.21                 0.513892      3.647399              272.0
# 102.0.0.15                 0.474900      4.709758              238.0
# 102.0.0.24                 0.338977      2.516611              102.0
# 102.0.0.19                 0.656844      7.607849              442.0
# 102.0.0.25                 0.268359      5.804508              238.0
# 102.0.0.23                 0.295689      3.159265              238.0
# 102.0.0.16                 0.292855      5.881367              272.0
# 102.0.0.20                 0.723031      4.030189              238.0
# 102.0.0.14                 0.285686      6.185177              340.0
# 102.0.0.26                 0.505433      2.048756              170.0
#
#             frame.len_range_ts  ip.len_range_ts  ip.flags.df_range_ts  \
# 102.0.0.4               1360.0           1080.0                  20.0
# 102.0.0.6               1496.0           1188.0                  22.0
# 102.0.0.7               3400.0           2700.0                  50.0
# 102.0.0.9               1632.0           1296.0                  24.0
# 102.0.0.10               816.0            648.0                  12.0
# 102.0.0.12              3264.0           2592.0                  48.0
# 102.0.0.11               680.0            540.0                  10.0
# 102.0.0.3               1496.0           1188.0                  22.0
# 102.0.0.13              1360.0           1080.0                  20.0
# 102.0.0.18              1632.0           1296.0                  24.0
# 102.0.0.17              1088.0            864.0                  16.0
# 102.0.0.21              1088.0            864.0                  16.0
# 102.0.0.15               952.0            756.0                  14.0
# 102.0.0.24               408.0            324.0                   6.0
# 102.0.0.19              1768.0           1404.0                  26.0
# 102.0.0.25               952.0            756.0                  14.0
# 102.0.0.23               952.0            756.0                  14.0
# 102.0.0.16              1088.0            864.0                  16.0
# 102.0.0.20               952.0            756.0                  14.0
# 102.0.0.14              1360.0           1080.0                  20.0
# 102.0.0.26               680.0            540.0                  10.0
#
#             ip.ttl_range_ts  frame.time_relative_range_ts  \
# 102.0.0.4            1260.0                   1341.490069
# 102.0.0.6            1386.0                   1681.970383
# 102.0.0.7            3150.0                   6978.281043
# 102.0.0.9            1512.0                   1773.826016
# 102.0.0.10            756.0                    932.695809
# 102.0.0.12           3024.0                   4862.021797
# 102.0.0.11            630.0                    978.924489
# 102.0.0.3            1386.0                   5903.906951
# 102.0.0.13           1260.0                   3489.379113
# 102.0.0.18           1512.0                   3137.740613
# 102.0.0.17           1008.0                   2676.370726
# 102.0.0.21           1008.0                   2048.030360
# 102.0.0.15            882.0                   2166.398603
# 102.0.0.24            378.0                    769.035869
# 102.0.0.19           1638.0                   3781.033751
# 102.0.0.25            882.0                   2163.055327
# 102.0.0.23            882.0                   2018.610562
# 102.0.0.16           1008.0                   2600.819726
# 102.0.0.20            882.0                   2714.152844
# 102.0.0.14           1260.0                   3096.948234
# 102.0.0.26            630.0                   2202.255833
#
#             frame.time_delta_range_ts  count_range_ts
# 102.0.0.4                    2.009184            20.0
# 102.0.0.6                    4.481238            22.0
# 102.0.0.7                    4.414567            50.0
# 102.0.0.9                    2.447907            24.0
# 102.0.0.10                   1.236301            12.0
# 102.0.0.12                   4.920457            48.0
# 102.0.0.11                   0.768497            10.0
# 102.0.0.3                    4.371028            22.0
# 102.0.0.13                   3.165218            20.0
# 102.0.0.18                   3.400134            24.0
# 102.0.0.17                   1.351710            16.0
# 102.0.0.21                   2.324367            16.0
# 102.0.0.15                   1.651111            14.0
# 102.0.0.24                   0.734567             6.0
# 102.0.0.19                   2.135597            26.0
# 102.0.0.25                   0.676831            14.0
# 102.0.0.23                   1.079399            14.0
# 102.0.0.16                   0.759606            16.0
# 102.0.0.20                   2.326021            14.0
# 102.0.0.14                   0.879396            20.0
# 102.0.0.26                   2.822854            10.0
#
# [21 rows x 50 columns]

# %%
import math
def ip_to_group(ip):
    if ip.split(".")[0] != '102':
        return -1
    return math.floor((int(ip.split(".")[-1])-2) / 5)
def get_real_label(df):
    data = df.index.values
    result = np.array([ip_to_group(xi) for xi in data])
    return result

# %%
answers = get_real_label(df)

# %%
# dt_features = ['frame.time_relative_mean', 'frame.time_relative_std']
# df = df[dt_features]

# %%
from sklearn import tree

X = df
Y = answers

clf = tree.DecisionTreeClassifier(random_state=0, max_depth=10)
clf = clf.fit(X, Y)

# %%
# !pip install graphviz
# sudo apt install -y graphviz
import graphviz 

dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=df.columns,  
                      class_names=Y.astype(str),  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in /home/taylor/.local/lib/python3.10/site-packages (0.20.1)

# %%
# best frame.time_relative_mean, frame.time_relative_std
# dt_features = ['frame.time_relative_mean', 'frame.time_relative_max', 'frame.time_delta_range']
# df = df[dt_features]

# %%
normalized_df=(df-df.min())/(df.max()-df.min())
normalized_df = normalized_df.fillna(0)
normalized_df
# Out:
#             frame.time_relative_mean  frame.time_delta_mean  \
# 102.0.0.4                   0.015454               0.659274
# 102.0.0.6                   0.000000               0.000976
# 102.0.0.7                   0.317268               0.000480
# 102.0.0.9                   0.061502               0.159481
# 102.0.0.10                  0.007750               0.669726
# 102.0.0.12                  0.341388               0.000827
# 102.0.0.11                  0.114425               1.000000
# 102.0.0.3                   1.000000               0.324022
# 102.0.0.13                  0.476284               0.157248
# 102.0.0.18                  0.290602               0.158472
# 102.0.0.17                  0.380007               0.000480
# 102.0.0.21                  0.296928               0.126420
# 102.0.0.15                  0.381394               0.168329
# 102.0.0.24                  0.312431               0.314430
# 102.0.0.19                  0.382141               0.115918
# 102.0.0.25                  0.403720               0.156537
# 102.0.0.23                  0.377086               0.161647
# 102.0.0.16                  0.442858               0.000000
# 102.0.0.20                  0.540708               0.000165
# 102.0.0.14                  0.416584               0.000761
# 102.0.0.26                  0.746561               0.487174
#
#             frame.time_relative_min  frame.time_delta_min  \
# 102.0.0.4                  0.000000              0.105263
# 102.0.0.6                  0.023963              0.000000
# 102.0.0.7                  0.079286              0.035088
# 102.0.0.9                  0.080442              0.631579
# 102.0.0.10                 0.094613              0.859649
# 102.0.0.12                 0.199817              0.000000
# 102.0.0.11                 0.207141              0.578947
# 102.0.0.3                  1.000000              0.596491
# 102.0.0.13                 0.312981              0.561404
# 102.0.0.18                 0.324154              0.578947
# 102.0.0.17                 0.338043              0.017544
# 102.0.0.21                 0.349275              0.368421
# 102.0.0.15                 0.380226              0.614035
# 102.0.0.24                 0.419195              0.438596
# 102.0.0.19                 0.429677              0.561404
# 102.0.0.25                 0.432610              0.578947
# 102.0.0.23                 0.460862              0.789474
# 102.0.0.16                 0.486381              0.052632
# 102.0.0.20                 0.573443              0.017544
# 102.0.0.14                 0.527400              0.105263
# 102.0.0.26                 0.549347              1.000000
#
#             frame.time_relative_max  frame.time_delta_max  \
# 102.0.0.4                  0.563757              0.155555
# 102.0.0.6                  0.970066              1.000000
# 102.0.0.7                  0.261795              0.255202
# 102.0.0.9                  0.000000              0.131699
# 102.0.0.10                 0.016187              0.193033
# 102.0.0.12                 0.386688              0.233533
# 102.0.0.11                 0.068494              0.029325
# 102.0.0.3                  1.000000              0.155360
# 102.0.0.13                 0.612566              0.552337
# 102.0.0.18                 0.281868              0.166150
# 102.0.0.17                 0.476215              0.152955
# 102.0.0.21                 0.442743              0.096739
# 102.0.0.15                 0.237184              0.091260
# 102.0.0.24                 0.176457              0.061586
# 102.0.0.19                 0.617048              0.222482
# 102.0.0.25                 0.237533              0.000000
# 102.0.0.23                 0.263942              0.066956
# 102.0.0.16                 0.318458              0.037710
# 102.0.0.20                 0.396065              0.142437
# 102.0.0.14                 0.312408              0.000036
# 102.0.0.26                 0.548276              0.270790
#
#             frame.time_relative_std  frame.time_delta_std  \
# 102.0.0.4                  0.632752              0.191165
# 102.0.0.6                  1.000000              1.000000
# 102.0.0.7                  0.441833              0.135895
# 102.0.0.9                  0.079838              0.110392
# 102.0.0.10                 0.132483              0.292374
# 102.0.0.12                 0.429637              0.185228
# 102.0.0.11                 0.107230              0.080665
# 102.0.0.3                  0.253818              0.260219
# 102.0.0.13                 0.392187              0.504584
# 102.0.0.18                 0.116285              0.176753
# 102.0.0.17                 0.262128              0.159089
# 102.0.0.21                 0.429696              0.131999
# 102.0.0.15                 0.138794              0.136678
# 102.0.0.24                 0.000000              0.090095
# 102.0.0.19                 0.249205              0.246270
# 102.0.0.25                 0.018765              0.000000
# 102.0.0.23                 0.053584              0.117752
# 102.0.0.16                 0.041540              0.047142
# 102.0.0.20                 0.091714              0.201269
# 102.0.0.14                 0.056455              0.002885
# 102.0.0.26                 0.367150              0.405782
#
#             frame.time_relative_range  frame.time_delta_range  ...  \
# 102.0.0.4                    0.660591                0.155561  ...
# 102.0.0.6                    1.000000                1.000000  ...
# 102.0.0.7                    0.334312                0.255208  ...
# 102.0.0.9                    0.102967                0.131697  ...
# 102.0.0.10                   0.106411                0.193027  ...
# 102.0.0.12                   0.352350                0.233539  ...
# 102.0.0.11                   0.066653                0.029325  ...
# 102.0.0.3                    0.282105                0.155358  ...
# 102.0.0.13                   0.464905                0.552333  ...
# 102.0.0.18                   0.165265                0.166149  ...
# 102.0.0.17                   0.325762                0.152962  ...
# 102.0.0.21                   0.287732                0.096741  ...
# 102.0.0.15                   0.083173                0.091259  ...
# 102.0.0.24                   0.000000                0.061588  ...
# 102.0.0.19                   0.379868                0.222480  ...
# 102.0.0.25                   0.043537                0.000000  ...
# 102.0.0.23                   0.045242                0.066952  ...
# 102.0.0.16                   0.073775                0.037718  ...
# 102.0.0.20                   0.075708                0.142444  ...
# 102.0.0.14                   0.037171                0.000043  ...
# 102.0.0.26                   0.228076                0.270781  ...
#
#             frame.time_delta_std_ts  count_std_ts  ip.proto_range_ts  \
# 102.0.0.4                  0.304904      0.151279           0.318182
# 102.0.0.6                  0.326005      0.118763           0.363636
# 102.0.0.7                  1.000000      1.000000           1.000000
# 102.0.0.9                  0.461819      0.295956           0.409091
# 102.0.0.10                 0.062922      0.021444           0.136364
# 102.0.0.12                 0.956781      0.592129           0.954545
# 102.0.0.11                 0.000000      0.050599           0.090909
# 102.0.0.3                  0.917310      0.300825           0.363636
# 102.0.0.13                 0.632250      0.250203           0.318182
# 102.0.0.18                 0.654612      0.368746           0.409091
# 102.0.0.17                 0.170508      0.202918           0.227273
# 102.0.0.21                 0.253030      0.104750           0.227273
# 102.0.0.15                 0.217942      0.174360           0.181818
# 102.0.0.24                 0.095630      0.030656           0.000000
# 102.0.0.19                 0.381668      0.364255           0.454545
# 102.0.0.25                 0.032083      0.246093           0.181818
# 102.0.0.23                 0.056676      0.072765           0.181818
# 102.0.0.16                 0.054125      0.251129           0.227273
# 102.0.0.20                 0.441228      0.129832           0.181818
# 102.0.0.14                 0.047675      0.271036           0.318182
# 102.0.0.26                 0.245418      0.000000           0.090909
#
#             frame.len_range_ts  ip.len_range_ts  ip.flags.df_range_ts  \
# 102.0.0.4             0.318182         0.318182              0.318182
# 102.0.0.6             0.363636         0.363636              0.363636
# 102.0.0.7             1.000000         1.000000              1.000000
# 102.0.0.9             0.409091         0.409091              0.409091
# 102.0.0.10            0.136364         0.136364              0.136364
# 102.0.0.12            0.954545         0.954545              0.954545
# 102.0.0.11            0.090909         0.090909              0.090909
# 102.0.0.3             0.363636         0.363636              0.363636
# 102.0.0.13            0.318182         0.318182              0.318182
# 102.0.0.18            0.409091         0.409091              0.409091
# 102.0.0.17            0.227273         0.227273              0.227273
# 102.0.0.21            0.227273         0.227273              0.227273
# 102.0.0.15            0.181818         0.181818              0.181818
# 102.0.0.24            0.000000         0.000000              0.000000
# 102.0.0.19            0.454545         0.454545              0.454545
# 102.0.0.25            0.181818         0.181818              0.181818
# 102.0.0.23            0.181818         0.181818              0.181818
# 102.0.0.16            0.227273         0.227273              0.227273
# 102.0.0.20            0.181818         0.181818              0.181818
# 102.0.0.14            0.318182         0.318182              0.318182
# 102.0.0.26            0.090909         0.090909              0.090909
#
#             ip.ttl_range_ts  frame.time_relative_range_ts  \
# 102.0.0.4          0.318182                      0.092194
# 102.0.0.6          0.363636                      0.147028
# 102.0.0.7          1.000000                      1.000000
# 102.0.0.9          0.409091                      0.161822
# 102.0.0.10         0.136364                      0.026357
# 102.0.0.12         0.954545                      0.659176
# 102.0.0.11         0.090909                      0.033803
# 102.0.0.3          0.363636                      0.826972
# 102.0.0.13         0.318182                      0.438112
# 102.0.0.18         0.409091                      0.381480
# 102.0.0.17         0.227273                      0.307177
# 102.0.0.21         0.227273                      0.205982
# 102.0.0.15         0.181818                      0.225046
# 102.0.0.24         0.000000                      0.000000
# 102.0.0.19         0.454545                      0.485083
# 102.0.0.25         0.181818                      0.224507
# 102.0.0.23         0.181818                      0.201244
# 102.0.0.16         0.227273                      0.295009
# 102.0.0.20         0.181818                      0.313261
# 102.0.0.14         0.318182                      0.374911
# 102.0.0.26         0.090909                      0.230820
#
#             frame.time_delta_range_ts  count_range_ts
# 102.0.0.4                    0.313966        0.318182
# 102.0.0.6                    0.896499        0.363636
# 102.0.0.7                    0.880788        1.000000
# 102.0.0.9                    0.417350        0.409091
# 102.0.0.10                   0.131838        0.136364
# 102.0.0.12                   1.000000        0.954545
# 102.0.0.11                   0.021601        0.090909
# 102.0.0.3                    0.870528        0.363636
# 102.0.0.13                   0.586382        0.318182
# 102.0.0.18                   0.641740        0.409091
# 102.0.0.17                   0.159034        0.227273
# 102.0.0.21                   0.388238        0.227273
# 102.0.0.15                   0.229587        0.181818
# 102.0.0.24                   0.013605        0.000000
# 102.0.0.19                   0.343755        0.454545
# 102.0.0.25                   0.000000        0.181818
# 102.0.0.23                   0.094864        0.181818
# 102.0.0.16                   0.019506        0.227273
# 102.0.0.20                   0.388628        0.181818
# 102.0.0.14                   0.047734        0.318182
# 102.0.0.26                   0.505705        0.090909
#
# [21 rows x 50 columns]

# %%
from sklearn import metrics
from statistics import mean

# compute cluster purity
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
def my_kMeans(df):
    df = df.copy(deep=True)
    kmeans = KMeans(n_clusters=8, random_state=0, n_init='auto')
    df.loc[:,'cluster'] = kmeans.fit_predict(df)# get centroids
    df.loc[:,'real_label'] = answers
    #plt.scatter(df['frame.time_relative_mean'], df['frame.time_delta_range'], c=answers, alpha = 1, s=10)

    s = 0
    total = 0
    for c in df['cluster'].unique():
        selection = df[df['cluster'] == c]
        p = purity_score(selection['real_label'], selection['cluster'])
        total += len(selection)
        s += p * len(selection)
        print(selection[['cluster', 'real_label']])
        print(str(c) + ": " + str(p))
    return df
df = my_kMeans(df[['frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_relative_range', 'ip.len_std_ts']])
print("Average purity: " + str(purity))
# Out:
#            cluster  real_label
# 102.0.0.4        4           0
# 102.0.0.6        4           0
# 4: 1.0
#            cluster  real_label
# 102.0.0.7        1           1
# 1: 1.0
#             cluster  real_label
# 102.0.0.9         6           1
# 102.0.0.3         6           0
# 102.0.0.13        6           2
# 102.0.0.25        6           4
# 102.0.0.16        6           2
# 102.0.0.14        6           2
# 6: 0.5
#             cluster  real_label
# 102.0.0.10        5           1
# 102.0.0.11        5           1
# 5: 1.0
#             cluster  real_label
# 102.0.0.12        2           2
# 2: 1.0
#             cluster  real_label
# 102.0.0.18        3           3
# 102.0.0.19        3           3
# 3: 1.0
#             cluster  real_label
# 102.0.0.17        0           3
# 102.0.0.21        0           3
# 102.0.0.15        0           2
# 102.0.0.20        0           3
# 0: 0.75
#             cluster  real_label
# 102.0.0.24        7           4
# 102.0.0.23        7           4
# 102.0.0.26        7           4
# 7: 1.0
# Average purity:             frame.time_delta_mean  frame.time_relative_min  \
# 102.0.0.4                0.020008                60.431418
# 102.0.0.6                0.000106                64.652442
# 102.0.0.7                0.000091                74.397351
# 102.0.0.9                0.004898                74.600939
# 102.0.0.10               0.020324                77.097061
# 102.0.0.12               0.000102                95.628411
# 102.0.0.11               0.030309                96.918547
# 102.0.0.3                0.009872               236.577613
# 102.0.0.13               0.004831               115.561874
# 102.0.0.18               0.004868               117.529933
# 102.0.0.17               0.000091               119.976473
# 102.0.0.21               0.003899               121.954838
# 102.0.0.15               0.005165               127.406765
# 102.0.0.24               0.009583               134.270946
# 102.0.0.19               0.003581               136.117317
# 102.0.0.25               0.004809               136.633989
# 102.0.0.23               0.004964               141.610551
# 102.0.0.16               0.000077               146.105561
# 102.0.0.20               0.000082               161.441251
# 102.0.0.14               0.000100               153.330965
# 102.0.0.26               0.014805               157.196715
#
#             frame.time_relative_range  ip.len_std_ts  cluster  real_label
# 102.0.0.4                  164.649236     235.305164        4           0
# 102.0.0.6                  243.054761     208.508041        4           0
# 102.0.0.7                   89.276890     934.754941        1           1
# 102.0.0.9                   35.834962     354.537123        6           1
# 102.0.0.10                  36.630628     128.305439        5           1
# 102.0.0.12                  93.443811     598.619150        2           2
# 102.0.0.11                  27.446181     152.332600        5           1
# 102.0.0.3                   77.216909     358.549251        6           0
# 102.0.0.13                 119.444690     316.830424        6           2
# 102.0.0.18                  50.226160     414.524588        3           3
# 102.0.0.17                  87.301850     277.861972        0           3
# 102.0.0.21                  78.516648     196.959548        0           3
# 102.0.0.15                  31.262540     254.326919        0           2
# 102.0.0.24                  12.048997     135.897020        7           4
# 102.0.0.19                  99.800606     410.823841        3           3
# 102.0.0.25                  22.106384     313.443407        6           4
# 102.0.0.23                  22.500151     170.600285        7           4
# 102.0.0.16                  29.091445     317.593811        6           2
# 102.0.0.20                  29.537935     217.630212        0           3
# 102.0.0.14                  20.635712     333.999539        6           2
# 102.0.0.26                  64.735889     110.632843        7           4

# %%
# Find best features 
import itertools
 
def findsubsets(s, n):
    return list(itertools.combinations(s, n))

def iterate_features(df, n):
    features = df.columns
    best_features = []
    best_score = 0.0
    for subset in findsubsets(features, n):
        subset = list(subset)
        score = my_kMeans(df[subset])

        if score > best_score:
            best_score = score
            best_features = subset
            print(best_score)
            print(best_features)
    return best_features

for n in range(1,5):
    best_features = iterate_features(df, n)
# Out:
# 0.5714285714285714
# ['frame.time_relative_mean']
# 0.7619047619047619
# ['frame.time_relative_min']
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 0.5714285714285714
# ['frame.time_relative_mean', 'frame.time_delta_mean']
# 0.6190476190476191
# ['frame.time_relative_mean', 'frame.time_relative_min']
# 0.6666666666666666
# ['frame.time_relative_mean', 'frame.time_relative_max']
# 0.7142857142857143
# ['frame.time_relative_mean', 'ip.proto_max_ts']
# 0.7619047619047619
# ['frame.time_relative_mean', 'ip.len_std_ts']
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 0.6190476190476191
# ['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_min']
# 0.6666666666666666
# ['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_max']
# 0.7142857142857143
# ['frame.time_relative_mean', 'frame.time_delta_mean', 'ip.proto_max_ts']
# 0.7619047619047619
# ['frame.time_relative_mean', 'frame.time_delta_mean', 'ip.len_std_ts']
# 0.8095238095238095
# ['frame.time_relative_min', 'frame.time_relative_range', 'ip.len_std_ts']
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 0.6190476190476191
# ['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_delta_min']
# 0.7619047619047619
# ['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_relative_std']
# 0.8095238095238095
# ['frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_relative_range', 'ip.len_std_ts']
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_

# %%
# Cluster and viz dns
# !pip install umap-learn numpy numba
# Dimension reduction and clustering libraries
#import umap.umap_ as umap
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: umap-learn in /home/taylor/.local/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: numpy in /home/taylor/.local/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: numba in /home/taylor/.local/lib/python3.10/site-packages (0.56.4)
# Requirement already satisfied: tqdm in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (4.64.1)
# Requirement already satisfied: scipy>=1.0 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (0.5.8)
# Requirement already satisfied: scikit-learn>=0.22 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (1.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/taylor/.local/lib/python3.10/site-packages (from numba) (0.39.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba) (59.6.0)
# Requirement already satisfied: joblib>=0.11 in /home/taylor/.local/lib/python3.10/site-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)

# %%
#normalized_df=(df-df.min())/(df.max()-df.min())
# standard_embedding = umap.UMAP(random_state=42).fit_transform(normalized_df)
# plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=normalized_df.cluster, s=10, cmap='Spectral');

# %%
# Cluster who this
Server_scope
# Out:
# ['data/argus/csv/myMarkovServer0-101.0.0.10.csv',
#  'data/csv/myMarkovServer0-101.0.0.10.csv']

# %%
def hex_col_to_str(df, col):
    df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))

# %%
# Cluster Server resources
## Create ts for each resource
resource_df = format_time_col(scope_to_df(pcap_only(Server_scope)), 'frame.time')
resource_df['frame.time'] = resource_df['frame.time'].apply(lambda x: x+Shadow_offset)
resource_df_filtered = resource_df[(resource_df['http.request'].notna())]
hex_col_to_str(resource_df_filtered, 'tcp.payload')
resource_df_filtered
# Out:
# /tmp/ipykernel_378350/2636449078.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))
#      frame.number                 frame.time           ip.src      ip.dst  \
# 3               4 2023-03-23 14:46:53.222932  185.220.101.141  101.0.0.10
# 13             14 2023-03-23 14:46:54.222933  185.220.101.141  101.0.0.10
# 23             24 2023-03-23 14:46:54.757713  185.220.101.141  101.0.0.10
# 33             34 2023-03-23 14:46:55.286493  185.220.101.141  101.0.0.10
# 43             44 2023-03-23 14:46:55.815273  185.220.101.141  101.0.0.10
# 53             54 2023-03-23 14:46:56.344053  185.220.101.141  101.0.0.10
# 63             64 2023-03-23 14:47:15.232154  185.220.101.141  101.0.0.10
# 73             74 2023-03-23 14:47:19.222932  185.220.101.141  101.0.0.10
# 83             84 2023-03-23 14:47:20.222933  185.220.101.141  101.0.0.10
# 93             94 2023-03-23 14:47:20.751713  185.220.101.141  101.0.0.10
# 103           104 2023-03-23 14:47:22.222933  185.220.101.141  101.0.0.10
# 113           114 2023-03-23 14:47:23.222932  185.220.101.141  101.0.0.10
# 123           124 2023-03-23 14:47:25.222933  185.220.101.141  101.0.0.10
#
#      ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
# 3           6        200     200            1            0          NaN  ...
# 13          6        200     200            1            0          NaN  ...
# 23          6        200     200            1            0          NaN  ...
# 33          6        200     200            1            0          NaN  ...
# 43          6        200     200            1            0          NaN  ...
# 53          6        200     200            1            0          NaN  ...
# 63          6        200     200            1            0          NaN  ...
# 73          6        200     200            1            0          NaN  ...
# 83          6        200     200            1            0          NaN  ...
# 93          6        200     200            1            0          NaN  ...
# 103         6        200     200            1            0          NaN  ...
# 113         6        200     200            1            0          NaN  ...
# 123         6        200     200            1            0          NaN  ...
#
#      dtls.handshake.extensions_key_share_client_length  http.request  \
# 3                                                  NaN           1.0
# 13                                                 NaN           1.0
# 23                                                 NaN           1.0
# 33                                                 NaN           1.0
# 43                                                 NaN           1.0
# 53                                                 NaN           1.0
# 63                                                 NaN           1.0
# 73                                                 NaN           1.0
# 83                                                 NaN           1.0
# 93                                                 NaN           1.0
# 103                                                NaN           1.0
# 113                                                NaN           1.0
# 123                                                NaN           1.0
#
#      udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
# 3         NaN             0.264390          0.163390           0.264390
# 13        NaN             1.264391          0.163390           0.264390
# 23        NaN             1.799171          0.163390           0.264390
# 33        NaN             2.327951          0.163390           0.264390
# 43        NaN             2.856731          0.163390           0.264390
# 53        NaN             3.385511          0.163390           0.264390
# 63        NaN            22.273612          0.172612           0.273612
# 73        NaN            26.264390          0.163390           0.264390
# 83        NaN            27.264391          0.163390           0.264390
# 93        NaN            27.793171          0.163390           0.264390
# 103       NaN            29.264391          0.163390           0.264390
# 113       NaN            30.264390          0.163390           0.264390
# 123       NaN            32.264391          0.163390           0.264390
#
#      tcp.time_delta                                        tcp.payload  \
# 3          0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 13         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 23         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 33         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 43         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 53         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 63         0.172612  474554202f7265736f75726365322e68746d6c20485454...
# 73         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 83         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 93         0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 103        0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 113        0.163390  474554202f7265736f75726365322e68746d6c20485454...
# 123        0.163390  474554202f7265736f75726365322e68746d6c20485454...
#
#      dns.qry.name                                    tcp.payload_str
# 3             NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 13            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 23            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 33            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 43            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 53            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 63            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 73            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 83            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 93            NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 103           NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 113           NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
# 123           NaN  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....
#
# [13 rows x 60 columns]

# %%
resource_df_filtered['resource'] = resource_df_filtered['tcp.payload_str'].apply(lambda x: x.split(' ')[1])
resource_df_filtered
# Out:
# /tmp/ipykernel_378350/2636449078.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))
# /tmp/ipykernel_378350/4127982458.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resource_df_filtered['resource'] = resource_df_filtered['tcp.payload_str'].apply(lambda x: x.split(' ')[1])
#      frame.number                 frame.time           ip.src      ip.dst  \
# 3               4 2023-03-23 14:46:53.222932  185.220.101.141  101.0.0.10
# 13             14 2023-03-23 14:46:54.222933  185.220.101.141  101.0.0.10
# 23             24 2023-03-23 14:46:54.757713  185.220.101.141  101.0.0.10
# 33             34 2023-03-23 14:46:55.286493  185.220.101.141  101.0.0.10
# 43             44 2023-03-23 14:46:55.815273  185.220.101.141  101.0.0.10
# 53             54 2023-03-23 14:46:56.344053  185.220.101.141  101.0.0.10
# 63             64 2023-03-23 14:47:15.232154  185.220.101.141  101.0.0.10
# 73             74 2023-03-23 14:47:19.222932  185.220.101.141  101.0.0.10
# 83             84 2023-03-23 14:47:20.222933  185.220.101.141  101.0.0.10
# 93             94 2023-03-23 14:47:20.751713  185.220.101.141  101.0.0.10
# 103           104 2023-03-23 14:47:22.222933  185.220.101.141  101.0.0.10
# 113           114 2023-03-23 14:47:23.222932  185.220.101.141  101.0.0.10
# 123           124 2023-03-23 14:47:25.222933  185.220.101.141  101.0.0.10
#
#      ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
# 3           6        200     200            1            0          NaN  ...
# 13          6        200     200            1            0          NaN  ...
# 23          6        200     200            1            0          NaN  ...
# 33          6        200     200            1            0          NaN  ...
# 43          6        200     200            1            0          NaN  ...
# 53          6        200     200            1            0          NaN  ...
# 63          6        200     200            1            0          NaN  ...
# 73          6        200     200            1            0          NaN  ...
# 83          6        200     200            1            0          NaN  ...
# 93          6        200     200            1            0          NaN  ...
# 103         6        200     200            1            0          NaN  ...
# 113         6        200     200            1            0          NaN  ...
# 123         6        200     200            1            0          NaN  ...
#
#      http.request  udp.port  frame.time_relative  frame.time_delta  \
# 3             1.0       NaN             0.264390          0.163390
# 13            1.0       NaN             1.264391          0.163390
# 23            1.0       NaN             1.799171          0.163390
# 33            1.0       NaN             2.327951          0.163390
# 43            1.0       NaN             2.856731          0.163390
# 53            1.0       NaN             3.385511          0.163390
# 63            1.0       NaN            22.273612          0.172612
# 73            1.0       NaN            26.264390          0.163390
# 83            1.0       NaN            27.264391          0.163390
# 93            1.0       NaN            27.793171          0.163390
# 103           1.0       NaN            29.264391          0.163390
# 113           1.0       NaN            30.264390          0.163390
# 123           1.0       NaN            32.264391          0.163390
#
#      tcp.time_relative  tcp.time_delta  \
# 3             0.264390        0.163390
# 13            0.264390        0.163390
# 23            0.264390        0.163390
# 33            0.264390        0.163390
# 43            0.264390        0.163390
# 53            0.264390        0.163390
# 63            0.273612        0.172612
# 73            0.264390        0.163390
# 83            0.264390        0.163390
# 93            0.264390        0.163390
# 103           0.264390        0.163390
# 113           0.264390        0.163390
# 123           0.264390        0.163390
#
#                                            tcp.payload  dns.qry.name  \
# 3    474554202f7265736f75726365322e68746d6c20485454...           NaN
# 13   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 23   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 33   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 43   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 53   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 63   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 73   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 83   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 93   474554202f7265736f75726365322e68746d6c20485454...           NaN
# 103  474554202f7265736f75726365322e68746d6c20485454...           NaN
# 113  474554202f7265736f75726365322e68746d6c20485454...           NaN
# 123  474554202f7265736f75726365322e68746d6c20485454...           NaN
#
#                                        tcp.payload_str         resource
# 3    GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 13   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 23   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 33   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 43   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 53   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 63   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 73   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 83   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 93   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 103  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 113  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
# 123  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#
# [13 rows x 61 columns]

# %%
resources = resource_df_filtered['resource'].unique()
flows_re = {}
flows_ts_re = {}
for resource in resources:
    flows_re[resource] = resource_df_filtered[(resource_df_filtered['resource'] == resource)]
    flows_ts_re[resource] = df_to_ts(flows_re[resource].copy()).set_index('frame.time')
# Out:
# /tmp/ipykernel_378350/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()

# %%
flows_re
# Out:
# {'/resource2.html':      frame.number                 frame.time           ip.src      ip.dst  \
#  3               4 2023-03-23 14:46:53.222932  185.220.101.141  101.0.0.10
#  13             14 2023-03-23 14:46:54.222933  185.220.101.141  101.0.0.10
#  23             24 2023-03-23 14:46:54.757713  185.220.101.141  101.0.0.10
#  33             34 2023-03-23 14:46:55.286493  185.220.101.141  101.0.0.10
#  43             44 2023-03-23 14:46:55.815273  185.220.101.141  101.0.0.10
#  53             54 2023-03-23 14:46:56.344053  185.220.101.141  101.0.0.10
#  63             64 2023-03-23 14:47:15.232154  185.220.101.141  101.0.0.10
#  73             74 2023-03-23 14:47:19.222932  185.220.101.141  101.0.0.10
#  83             84 2023-03-23 14:47:20.222933  185.220.101.141  101.0.0.10
#  93             94 2023-03-23 14:47:20.751713  185.220.101.141  101.0.0.10
#  103           104 2023-03-23 14:47:22.222933  185.220.101.141  101.0.0.10
#  113           114 2023-03-23 14:47:23.222932  185.220.101.141  101.0.0.10
#  123           124 2023-03-23 14:47:25.222933  185.220.101.141  101.0.0.10
#
#       ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  3           6        200     200            1            0          NaN  ...
#  13          6        200     200            1            0          NaN  ...
#  23          6        200     200            1            0          NaN  ...
#  33          6        200     200            1            0          NaN  ...
#  43          6        200     200            1            0          NaN  ...
#  53          6        200     200            1            0          NaN  ...
#  63          6        200     200            1            0          NaN  ...
#  73          6        200     200            1            0          NaN  ...
#  83          6        200     200            1            0          NaN  ...
#  93          6        200     200            1            0          NaN  ...
#  103         6        200     200            1            0          NaN  ...
#  113         6        200     200            1            0          NaN  ...
#  123         6        200     200            1            0          NaN  ...
#
#       http.request  udp.port  frame.time_relative  frame.time_delta  \
#  3             1.0       NaN             0.264390          0.163390
#  13            1.0       NaN             1.264391          0.163390
#  23            1.0       NaN             1.799171          0.163390
#  33            1.0       NaN             2.327951          0.163390
#  43            1.0       NaN             2.856731          0.163390
#  53            1.0       NaN             3.385511          0.163390
#  63            1.0       NaN            22.273612          0.172612
#  73            1.0       NaN            26.264390          0.163390
#  83            1.0       NaN            27.264391          0.163390
#  93            1.0       NaN            27.793171          0.163390
#  103           1.0       NaN            29.264391          0.163390
#  113           1.0       NaN            30.264390          0.163390
#  123           1.0       NaN            32.264391          0.163390
#
#       tcp.time_relative  tcp.time_delta  \
#  3             0.264390        0.163390
#  13            0.264390        0.163390
#  23            0.264390        0.163390
#  33            0.264390        0.163390
#  43            0.264390        0.163390
#  53            0.264390        0.163390
#  63            0.273612        0.172612
#  73            0.264390        0.163390
#  83            0.264390        0.163390
#  93            0.264390        0.163390
#  103           0.264390        0.163390
#  113           0.264390        0.163390
#  123           0.264390        0.163390
#
#                                             tcp.payload  dns.qry.name  \
#  3    474554202f7265736f75726365322e68746d6c20485454...           NaN
#  13   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  23   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  33   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  43   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  53   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  63   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  73   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  83   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  93   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  103  474554202f7265736f75726365322e68746d6c20485454...           NaN
#  113  474554202f7265736f75726365322e68746d6c20485454...           NaN
#  123  474554202f7265736f75726365322e68746d6c20485454...           NaN
#
#                                         tcp.payload_str         resource
#  3    GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  13   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  23   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  33   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  43   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  53   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  63   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  73   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  83   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  93   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  103  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  113  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  123  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#
#  [13 rows x 61 columns]}

# %%
import numpy as np
def generate_features_resource(df, flow):
    features = []
    # 'first_seen'
    #features += [float(df['frame.time'].min().timestamp())]
    features += [df['frame.time'].min()]
    # 'last_seen'
    #features += [float(df['frame.time'].max().timestamp())]
    features += [df['frame.time'].max()]
    # 'reqs_per_sec'
    features += [flow['count'].mean()]
    # 'reqs_per_sec_std'
    val = flow['count'].std()
    features += [0 if np.isnan(val) else val]
    # 'total_req'
    features += [len(df)]
    # 'reqs_max'
    features += [flow['count'].max()]
    # 'reqs_min'
    features += [flow['count'].min()]
    return [features]
## Get flow features
cols = ['first_seen','last_seen', 'reqs_per_sec', 'reqs_per_sec_std', 'total_req', 'reqs_max', 'reqs_min']
index = []
feature_data = []
for ip in flows_re:
    index += [ip]
    feature_data += generate_features_resource(flows_re[ip], flows_ts_re[ip])

  
# Create the pandas DataFrame
df_resource = pd.DataFrame(feature_data, columns=cols, index=index)
df_resource
# Out:
#                                 first_seen                  last_seen  \
# /resource2.html 2023-03-23 14:46:53.222932 2023-03-23 14:47:25.222933
#
#                  reqs_per_sec  reqs_per_sec_std  total_req  reqs_max  reqs_min
# /resource2.html      2.166667          2.389591         13       6.0       0.0

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

for f in flows_ts_re:
    flows_ts_re[f]['count'].plot(label=f)
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
  
# adding legend to the curve
plt.legend()

# %%
# Link
# Which group has what signal
cluser_col_name = 'cluster' # 'real_label'

groups = df[cluser_col_name].unique()
dtypes = list(flows_ts_ip.values())[0].dtypes.to_dict()
cols = list(list(flows_ts_ip.values())[0].columns)
sum_ts = {}
for group in groups:
    sum_ts[group] = pd.DataFrame(columns=cols)
    sum_ts[group].astype(dtypes)
    #sum_ts[group].set_index('frame.time')
for ip in df.index.tolist():
    s = flows_ts_ip[ip].add(sum_ts[df.loc[ip][cluser_col_name]], fill_value=0)
    sum_ts[df.loc[ip][cluser_col_name]] = s

# %%
# normalize ts

# %%
# resource_and_groups = sum_ts + flows_ts_re
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

limit = 300

for f in flows_ts_re:
     flows_ts_re[f]['count'].head(limit).plot(label=f)
for f in sum_ts:
    #print(min(sum_ts[f].index.values)  - (10 * 1000000000))
    if f == -1: # Don't plot resolver
        continue
    sum_ts[f]['count'].div(4).head(limit).plot(label=f)
    
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
plt.ylabel('Packets (scaled)')
  
# adding legend to the curve
plt.legend()

# %%
# Find mathing groups for resources
# !pip install pyts

from pyts.metrics import dtw, itakura_parallelogram, sakoe_chiba_band
from pyts.metrics.dtw import (cost_matrix, accumulated_cost_matrix,
                              _return_path, _blurred_path_region)

def compare_ts(ts1, ts2):
    dtw_classic, path_classic = dtw(ts1, ts2, dist='square',
                                method='classic', return_path=True)
    return dtw_classic

def normalize_ts(ts):
    ts=(ts-ts.min())/(ts.max()-ts.min())
    return ts.fillna(0)

def compare_ts_reshape(ts1, ts2):
    ts1_norm = ts1.copy(deep=True)
    ts2_norm = ts2.copy(deep=True)
    
    buffer_room = 30 # in seconds
    delay = 120
    
    # lock to same range with buffer room on each side to account for network (or PPT) delay
    start = min(ts1.index.values) + (delay * 1000000000) - (buffer_room * 1000000000)
    end = max(ts1.index.values) + (buffer_room * 1000000000)+ (delay * 1000000000)
#     print("start: " + str(start))
#     print("end: " + str(end))
    #print(end - start)
    
#     ts1_norm = ts1_norm[start:end]
    ts2_norm = ts2_norm[start:end]
   # print(len(ts2_norm))
    
    # detect if no overlap
    if len(ts1_norm) < 2 or len(ts2_norm) < 2:
        return float("inf")
    
    # Normalize peaks?
    ts1_norm = normalize_ts(ts1_norm)
    ts2_norm = normalize_ts(ts2_norm)

    return compare_ts(ts1_norm, ts2_norm)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyts in /home/taylor/.local/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: numba>=0.48.0 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (0.56.4)
# Requirement already satisfied: scipy>=1.3.0 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.1 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.2.1)
# Requirement already satisfied: numpy>=1.17.5 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.23.5)
# Requirement already satisfied: joblib>=0.12 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/taylor/.local/lib/python3.10/site-packages (from numba>=0.48.0->pyts) (0.39.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba>=0.48.0->pyts) (59.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn>=0.22.1->pyts) (3.1.0)

# %%
answer = {'/resource0.html': 0, '/resource1.html': 1, '/resource2.html': 2, '/resource3.html': 3, '/resource4.html': 4}
num_correct = 0.0
for f in flows_ts_re:
    print(f)
    best_group = -1
    best_sim = -1
    for c in sum_ts:
        if len(sum_ts[c]['count']) < 2:
            print("\tGroup " + str(c) + " is too short. Skipping")
            continue
        sim = compare_ts_reshape(flows_ts_re[f]['count'], sum_ts[c]['count'].div(1))
        print("\tGroup " + str(c) + "\t\tSim:" + str(sim))
        if best_group == -1 or best_sim > sim:
            best_group = c
            best_sim = sim
    print("\n\tBest match is group " + str(best_group) + " with sim " + str(best_sim))
    if answer[f] == best_group:
        print('Correct!\n\n')
        num_correct += 1
print(str(num_correct/len(answer) *100) + "% Correct")
# Out:
# /resource0.html
# 	Group 7		Sim:2.426280866465221
# 	Group 1		Sim:1.8483407792838504
# 	Group 3		Sim:3.169782431202032
# 	Group 0		Sim:2.461373036983301
# 	Group 5		Sim:2.418196068140425
# 	Group 2		Sim:2.501580767452481
# 	Group 6		Sim:2.5219081389212117
# 	Group 4		Sim:3.2807099614625628
#
# 	Best match is group 1 with sim 1.8483407792838504
# /resource1.html
# 	Group 7		Sim:1.232950350792493
# 	Group 1		Sim:2.3533028965557015
# 	Group 3		Sim:1.1102383264189941
# 	Group 0		Sim:1.0464830659955326
# 	Group 5		Sim:1.2457643615321339
# 	Group 2		Sim:2.835163934879769
# 	Group 6		Sim:inf
# 	Group 4		Sim:2.709482763760421
#
# 	Best match is group 0 with sim 1.0464830659955326
# /resource2.html
# 	Group 7		Sim:2.2798809492728167
# 	Group 1		Sim:1.0346796933362163
# 	Group 3		Sim:1.3706644799314642
# 	Group 0		Sim:1.6260789196903178
# 	Group 5		Sim:0.8123110449890311
# 	Group 2		Sim:2.6234843372940513
# 	Group 6		Sim:3.464122071081793
# 	Group 4		Sim:2.8526840207862088
#
# 	Best match is group 5 with sim 0.8123110449890311
# /resource3.html
# 	Group 7		Sim:2.4014988539581137
# 	Group 1		Sim:2.595606756417014
# 	Group 3		Sim:1.3032276726895833
# 	Group 0		Sim:1.1081599546146266
# 	Group 5		Sim:1.2804550439079454
# 	Group 2		Sim:3.05636938537464
# 	Group 6		Sim:2.899908180550086
# 	Group 4		Sim:2.9074073934485503
#
# 	Best match is group 0 with sim 1.1081599546146266
# /resource4.html
# 	Group 7		Sim:1.6595375187909192
# 	Group 1		Sim:1.7354070619928537
# 	Group 3		Sim:4.413346516124007
# 	Group 0		Sim:1.1266487898472357
# 	Group 5		Sim:1.1158705352029936
# 	Group 2		Sim:2.570181294788278
# 	Group 6		Sim:3.6783651797845525
# 	Group 4		Sim:2.662656540810025
#
# 	Best match is group 5 with sim 1.1158705352029936
# 0.0% Correct

# %%
0.5714285714285714
['frame.time_relative_mean']
0.7619047619047619
['frame.time_relative_min']

0.5714285714285714
['frame.time_relative_mean', 'frame.time_delta_mean']
0.6190476190476191
['frame.time_relative_mean', 'frame.time_relative_min']
0.6666666666666666
['frame.time_relative_mean', 'frame.time_relative_max']
0.7142857142857143
['frame.time_relative_mean', 'ip.proto_max_ts']
0.7619047619047619
['frame.time_relative_mean', 'ip.len_std_ts']

0.6190476190476191
['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_min']
0.6666666666666666
['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_max']
0.7142857142857143
['frame.time_relative_mean', 'frame.time_delta_mean', 'ip.proto_max_ts']
0.7619047619047619
['frame.time_relative_mean', 'frame.time_delta_mean', 'ip.len_std_ts']
0.8095238095238095
['frame.time_relative_min', 'frame.time_relative_range', 'ip.len_std_ts']

0.6190476190476191
['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_delta_min']
0.7619047619047619
['frame.time_relative_mean', 'frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_relative_std']
0.8095238095238095
['frame.time_delta_mean', 'frame.time_relative_min', 'frame.time_relative_range', 'ip.len_std_ts']
