# %%
! pip install pandas matplotlib
# Knapsack NP complete could work
# or check for candidate DNSers that would be apart of the resource access and with enough resource access and DNS 
# could probably determine\


# What if determine candicate from DNSers like above but then look at their input to tor (frame size and timing 
# input and output with TDA to filter down candidates)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/taylor/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: matplotlib in /home/taylor/.local/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/taylor/.local/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/taylor/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/taylor/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Get argus flows from PCAPs
# !../util/process_data_argus.sh
# Out:
# ../util/process_data_argus.sh: line 3: 304477 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304489]: 15:44:50.758636 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304539]: 15:44:53.818856 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304546 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304558]: 15:44:56.928219 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304564]: 15:44:57.939474 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304571]: 15:44:58.954076 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304583]: 15:44:59.965834 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304624]: 15:45:02.004836 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304630]: 15:45:03.013873 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304636]: 15:45:04.025847 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304642]: 15:45:05.037620 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304648]: 15:45:06.055099 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304654 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304665]: 15:45:09.156540 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304671]: 15:45:10.165252 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304679]: 15:45:11.178761 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304685]: 15:45:12.189349 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304691 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304702]: 15:45:15.282658 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304708]: 15:45:16.294550 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304714]: 15:45:17.303346 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304724]: 15:45:18.314975 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304730 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304741]: 15:45:21.416343 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304749]: 15:45:22.424494 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304756]: 15:45:23.436736 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304768]: 15:45:24.445426 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304779]: 15:45:25.457035 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304805 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304817]: 15:45:28.563778 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304824]: 15:45:29.572088 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304830]: 15:45:30.583207 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304836]: 15:45:31.606287 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304842]: 15:45:32.617197 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304848]: 15:45:33.629023 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304854]: 15:45:34.637561 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304860]: 15:45:35.649150 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304866]: 15:45:36.657361 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304872]: 15:45:37.669005 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304878]: 15:45:38.677721 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304885]: 15:45:39.690275 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304891]: 15:45:40.698692 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304897]: 15:45:41.706952 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304903 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304916]: 15:45:44.803052 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304922 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304933]: 15:45:47.907133 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304939]: 15:45:48.919084 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304945]: 15:45:49.927641 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304951]: 15:45:50.937617 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304958]: 15:45:51.949381 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[304964]: 15:45:52.958066 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 304970 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[304985]: 15:45:56.053097 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[304991]: 15:45:57.067315 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 305003 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[305015]: 15:46:01.171915 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[305028]: 15:46:02.184140 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[305040]: 15:46:04.204516 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[305046]: 15:46:05.213467 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[305052]: 15:46:06.225055 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[305058]: 15:46:07.233767 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ../util/process_data_argus.sh: line 3: 305064 Segmentation fault      (core dumped) ra -r $filename.argus -c',' -s srcid rank stime ltime trans flgs seq dur runtime idle mean stddev sum min max smac dmac soui doui saddr daddr proto sport dport stos dtos sdsb ddsb sco dco sttl dttl shops dhops sipid dipid smpls dmpls autoid sas das ias cause nstroke snstroke dnstroke pkts spkts dpkts bytes sbytes dbytes appbytes sappbytes dappbytes pcr load sload dload loss sloss dloss ploss psloss pdloss retrans sretrans dretrans pretrans psretrans pdretrans sgap dgap rate srate drate dir sintpkt sintdist sintpktact sintdistact sintpktidl sintdistidl dintpkt dintdist dintpktact dintdistact dintpktidl dintdistidl sjit sjitact sjitidle djit djitact djitidle state label suser duser swin dwin svlan dvlan svid dvid svpri dvpri srng erng stcpb dtcpb tcprtt synack ackdat tcpopt inode offset smeansz dmeansz spktsz smaxsz dpktsz dmaxsz sminsz dminsz dminsz > $filename.csv
# ra[305075]: 15:46:10.329078 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[305081]: 15:46:11.341230 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[305087]: 15:46:12.349840 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# ra[305093]: 15:46:13.360969 ArgusGenerateRecordStruct: pre ARGUS_DATA_DSR len is zero
# ra[305099]: 15:46:14.369634 ArgusGenerateRecordStruct: post ARGUS_DATA_DSR len is zero
# mkdir: cannot create directory ‘data/argus’: File exists
# mkdir: cannot create directory ‘data/argus/csv’: File exists

# %%
# PCAP to CSV
# !../util/pcap_to_csv.sh
# Out:
# mkdir: cannot create directory ‘data/csv’: File exists

# %%
# PCAPNG to CSV
# !../util/pcapng_to_csv.sh
# Out:
# mkdir: cannot create directory ‘data/csv’: File exists

# %%
from os import listdir
from os.path import isfile, join

def getFilenames(path):
    return [path+f for f in listdir(path) if isfile(join(path, f))]

# %%
# Get argus data
arguspath = "data/argus/csv/"
argusCSVs = getFilenames(arguspath)

# Get pcap data
pcappath = "data/csv/"
pcapCSVs = getFilenames(pcappath)
data = argusCSVs + pcapCSVs

# %%
import pandas as pd

# %%
df = pd.read_csv (pcapCSVs[0])
df
# Out:
#        frame.number                           frame.time     ip.src  \
# 0                 1  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 1                 2  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 2                 3  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 3                 4  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 4                 5  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# ...             ...                                  ...        ...
# 16311         16312  Dec 31, 1969 19:59:58.496652000 EST  127.0.0.1
# 16312         16313  Dec 31, 1969 19:59:59.491652000 EST  127.0.0.1
# 16313         16314  Dec 31, 1969 19:59:59.491652000 EST  127.0.0.1
# 16314         16315  Dec 31, 1969 19:59:59.496652000 EST  127.0.0.1
# 16315         16316  Dec 31, 1969 19:59:59.496652000 EST  127.0.0.1
#
#           ip.dst  ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  \
# 0      127.0.0.1         6         40      40            1            0
# 1      127.0.0.1         6         40      40            1            0
# 2      127.0.0.1         6         40      40            1            0
# 3      127.0.0.1         6         40      40            1            0
# 4      127.0.0.1         6         65      65            1            0
# ...          ...       ...        ...     ...          ...          ...
# 16311  127.0.0.1         6         40      40            1            0
# 16312  127.0.0.1         6         53      53            1            0
# 16313  127.0.0.1         6         53      53            1            0
# 16314  127.0.0.1         6         40      40            1            0
# 16315  127.0.0.1         6         40      40            1            0
#
#        ip.fragment  ...  dtls.handshake.extensions_alpn_str_len  \
# 0              NaN  ...                                     NaN
# 1              NaN  ...                                     NaN
# 2              NaN  ...                                     NaN
# 3              NaN  ...                                     NaN
# 4              NaN  ...                                     NaN
# ...            ...  ...                                     ...
# 16311          NaN  ...                                     NaN
# 16312          NaN  ...                                     NaN
# 16313          NaN  ...                                     NaN
# 16314          NaN  ...                                     NaN
# 16315          NaN  ...                                     NaN
#
#        dtls.handshake.extensions_key_share_client_length  http.request  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 16311                                                NaN           NaN
# 16312                                                NaN           NaN
# 16313                                                NaN           NaN
# 16314                                                NaN           NaN
# 16315                                                NaN           NaN
#
#        udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
# 0           NaN             0.000000             0.000           0.000000
# 1           NaN             0.000000             0.000           0.000000
# 2           NaN             0.000000             0.000           0.000000
# 3           NaN             0.000000             0.000           0.000000
# 4           NaN             0.000000             0.000           0.000000
# ...         ...                  ...               ...                ...
# 16311       NaN          3357.496652             0.000        3357.496652
# 16312       NaN          3358.491652             0.995        3358.491652
# 16313       NaN          3358.491652             0.000        3358.491652
# 16314       NaN          3358.496652             0.005        3358.496652
# 16315       NaN          3358.496652             0.000        3358.496652
#
#        tcp.time_delta                                        tcp.payload  \
# 0               0.000                                                NaN
# 1               0.000                                                NaN
# 2               0.000                                                NaN
# 3               0.000                                                NaN
# 4               0.000  41555448454e544943415445202270617373776f726422...
# ...               ...                                                ...
# 16311           0.000                                                NaN
# 16312           0.995                         36353020425720302031330d0a
# 16313           0.000                         36353020425720302031330d0a
# 16314           0.005                                                NaN
# 16315           0.000                                                NaN
#
#       dns.qry.name
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 16311          NaN
# 16312          NaN
# 16313          NaN
# 16314          NaN
# 16315          NaN
#
# [16316 rows x 59 columns]

# %%
len(data)
# Out:
# 148

# %%
len(argusCSVs)
# Out:
# 74

# %%
# Basic Scopes
import re

# Get all clients and ISP dns scope
r = re.compile(".*isp.csv|.*Client[0-9]*-(?!127\.0\.0\.1)[0-9]*.[0-9]*.[0-9]*.[0-9]*..csv")
ISP_scope = list(filter(r.match, data))

# Access to public resolver scope
r = re.compile(".*isp.csv")
Access_resolver = list(filter(r.match, data))

# DNS Scope
r = re.compile("(.*tld|.*root-server|.*sld).csv")
Access_to_auth_zone = list(filter(r.match, data))

# Access Tor Scope
r = re.compile(".*Client[0-9]*-(?!127\.0\.0\.1)[0-9]*.[0-9]*.[0-9]*.[0-9]*..csv")
Access_tor = list(filter(r.match, data))

# Server Public Scope
r = re.compile(".*myMarkovServer0*-(?!127\.0\.0\.1)[0-9]*\.[0-9]*\.[0-9]*\.[0-9]*.csv")
Server_scope = list(filter(r.match, data))

# tor Exit scope
r = re.compile(".*exit.*")
Tor_exit_Scope = list(filter(r.match, data))

# tor Guard scope
r = re.compile(".*guard.*")
Tor_guard_Scope = list(filter(r.match, data))

# tor Relay scope
r = re.compile(".*relay.*")
Tor_relay_Scope = list(filter(r.match, data))

# tor Middle scope
r = re.compile(".*middle.*")
Tor_middle_Scope = list(filter(r.match, data))

# tor 4uthority scope
r = re.compile(".*4uthority.*")
Tor_4uthority_Scope = list(filter(r.match, data))

# resolver scope
r = re.compile(".*resolver.*")
resolver_Scope = list(filter(r.match, data))

# %%
def pcap_only(lis):
    r = re.compile(".*data/csv.*")
    return list(filter(r.match, lis))

def format_time_col(df, time_col):
    time_format='%b %d, %Y %X.%f'
    df[time_col] = df[time_col].apply(lambda x: datetime.strptime(x[:-7], time_format))
    df.set_index(time_col)
    return df

def scope_to_df(scope):
    df = pd.DataFrame()
    for f in scope:
        ddf = pd.read_csv (f)
        df = pd.concat([df, ddf])
    return df

# %%
from datetime import datetime

def df_to_ts(df):
    df['count'] = 1
    #  Minute is T
    return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()

# %%
# get start time for GNS3
GNS3_data = format_time_col(scope_to_df(pcap_only(Access_resolver + Access_to_auth_zone)), 'frame.time')
GNS3_starttime = GNS3_data.head(1)['frame.time'].tolist()[0]
Shadow_starttime = datetime.strptime('Dec 31, 1969 19:30:00', '%b %d, %Y %X')
Shadow_offset = GNS3_starttime - Shadow_starttime
Shadow_offset
# Out:
# Timedelta('19436 days 19:42:58.247604')

# %%
dns_df = format_time_col(scope_to_df(pcap_only(Access_to_auth_zone)), 'frame.time')

# %%
# Steps
# Who do this
# Cluster of who this
# Cluster per scope? all scopes?
# Link Clusters

# %%
# Assume range is whole experiment
# Justification: Looking for first group and all groups at same time (30 minute range, In future should have comms
# going on that start before we are looking [noise])

# %%
# Cluster DNS
## Create ts for each IP
resolv_df = format_time_col(scope_to_df(pcap_only(resolver_Scope)), 'frame.time')
DNS_PROTO = 17.0
resolv_df_filtered = resolv_df[resolv_df['ip.proto'] == DNS_PROTO]
IPs = resolv_df_filtered['ip.src'].unique()
flows_ip = {}
flows_ts_ip = {}
resolver_ip = '192.168.150.10'
evil_domain = 'evil.dne'
for ip in IPs:
    if ip != resolver_ip:
        flows_ip[ip] = resolv_df_filtered[((resolv_df_filtered['ip.dst'] == ip) | \
                                           (resolv_df_filtered['ip.src'] == ip))  \
                                         & (resolv_df_filtered['dns.qry.name'] == evil_domain)]
        temp = df_to_ts(flows_ip[ip].copy()).set_index('frame.time')
        if len(temp) > 0:
            flows_ts_ip[ip] = temp
# Out:
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()

# %%
flows_ip[ip]['dns.qry.name'].unique()
# Out:
# array(['evil.dne'], dtype=object)

# %%
flows_ts_ip[ip]['count']
# Out:
# frame.time
# 2023-03-20 15:16:26    28.0
# 2023-03-20 15:16:27    16.0
# 2023-03-20 15:16:28    20.0
# 2023-03-20 15:16:29    20.0
# 2023-03-20 15:16:30    16.0
# 2023-03-20 15:16:31    16.0
# 2023-03-20 15:16:32    16.0
# 2023-03-20 15:16:33    16.0
# 2023-03-20 15:16:34    20.0
# 2023-03-20 15:16:35    20.0
# 2023-03-20 15:16:36    28.0
# 2023-03-20 15:16:37    28.0
# 2023-03-20 15:16:38    24.0
# 2023-03-20 15:16:39    28.0
# 2023-03-20 15:16:40    20.0
# 2023-03-20 15:16:41    20.0
# 2023-03-20 15:16:42    20.0
# 2023-03-20 15:16:43    32.0
# 2023-03-20 15:16:44    36.0
# 2023-03-20 15:16:45    44.0
# 2023-03-20 15:16:46    40.0
# Name: count, dtype: float64

# %%
## Viz
# importing Libraries
  
# import pandas as pd
import pandas as pd
  
# importing matplotlib module
import matplotlib.pyplot as plt
plt.style.use('default')
  
# %matplotlib inline: only draw static
# images in the notebook
# %matplotlib inline

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

for f in flows_ts_ip:
    flows_ts_ip[f]['count'].plot(label=f)
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
plt.ylabel('Requests (seconds)')
  
# adding legend to the curve
plt.legend()

# %%
# !pip install scikit-learn
from sklearn.cluster import KMeans
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/taylor/.local/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)

# %%
def generate_features(df, flow):
    features = []
    # 'first_seen'
    features += [float(df['frame.time'].min().timestamp())]
    # 'last_seen'
    features += [float(df['frame.time'].max().timestamp())]
    # 'reqs_per_sec'
    features += [flow['count'].mean()]
    # 'reqs_per_sec_std'
    val = flow['count'].std()
    features += [0 if np.isnan(val) else val]
    # 'total_req'
    features += [len(df)]
    # 'reqs_max'
    features += [flow['count'].max()]
    # 'reqs_min'
    features += [flow['count'].min()]
    return [features]
## Get flow features
cols = ['first_seen','last_seen', 'reqs_per_sec', 'reqs_per_sec_std', 'total_req', 'reqs_max', 'reqs_min']
index = []
feature_data = []
for ip in flows_ts_ip:
    index += [ip]
    feature_data += generate_features(flows_ip[ip], flows_ts_ip[ip])

  
# Create the pandas DataFrame
df = pd.DataFrame(feature_data, columns=cols, index=index)
df
# Out:
#                first_seen     last_seen  reqs_per_sec  reqs_per_sec_std  \
# 102.0.0.4    1.679325e+09  1.679325e+09      5.566879          9.022247
# 172.20.0.11  1.679325e+09  1.679332e+09      0.512349          2.816483
# 172.20.0.12  1.679325e+09  1.679332e+09      3.072920         20.599791
# 102.0.0.7    1.679325e+09  1.679325e+09     24.938272         34.528374
# 102.0.0.6    1.679325e+09  1.679326e+09      2.417021          7.757856
# 102.0.0.9    1.679325e+09  1.679325e+09     30.357143         13.075888
# 102.0.0.8    1.679325e+09  1.679331e+09      0.186335          2.700550
# 102.0.0.5    1.679325e+09  1.679329e+09      0.196476          1.888719
# 102.0.0.10   1.679325e+09  1.679325e+09      1.428571          5.014265
# 102.0.0.12   1.679325e+09  1.679325e+09     21.552941         21.216293
# 102.0.0.11   1.679325e+09  1.679325e+09      3.052632          4.915663
# 102.0.0.2    1.679325e+09  1.679326e+09      2.205072          7.036161
# 102.0.0.18   1.679325e+09  1.679325e+09     19.761905         15.379444
# 102.0.0.17   1.679325e+09  1.679325e+09     13.316456         10.247632
# 102.0.0.13   1.679325e+09  1.679325e+09      9.285714         11.692323
# 102.0.0.22   1.679325e+09  1.679332e+09      0.468444          4.974416
# 102.0.0.21   1.679325e+09  1.679325e+09      6.197183          7.791240
# 102.0.0.24   1.679325e+09  1.679325e+09     17.000000          5.033223
# 102.0.0.25   1.679325e+09  1.679325e+09     10.571429         11.699535
# 102.0.0.15   1.679325e+09  1.679325e+09      8.000000          9.341987
# 102.0.0.23   1.679325e+09  1.679325e+09     12.266667          6.318529
# 102.0.0.19   1.679325e+09  1.679325e+09      9.869565         15.604464
# 102.0.0.3    1.679325e+09  1.679326e+09     12.314286         13.256164
# 102.0.0.16   1.679325e+09  1.679325e+09     18.857143         11.323806
# 102.0.0.26   1.679325e+09  1.679325e+09      2.385965          4.130697
# 102.0.0.14   1.679325e+09  1.679325e+09      9.538462         12.705743
# 102.0.0.20   1.679325e+09  1.679325e+09     24.190476          8.243901
#
#              total_req  reqs_max  reqs_min
# 102.0.0.4          102      40.0       0.0
# 172.20.0.11        354      20.0       0.0
# 172.20.0.12       2108     260.0       0.0
# 102.0.0.7          240     100.0       0.0
# 102.0.0.6           64      44.0       0.0
# 102.0.0.9          120      56.0       8.0
# 102.0.0.8          132      76.0       0.0
# 102.0.0.5           84      36.0       0.0
# 102.0.0.10          28      24.0       0.0
# 102.0.0.12         236      92.0       0.0
# 102.0.0.11          28      20.0       0.0
# 102.0.0.2          240      60.0       0.0
# 102.0.0.18         112      48.0       0.0
# 102.0.0.17         124      32.0       0.0
# 102.0.0.13         124      40.0       0.0
# 102.0.0.22         344     104.0       0.0
# 102.0.0.21          72      32.0       0.0
# 102.0.0.24          40      24.0      12.0
# 102.0.0.25          32      28.0       0.0
# 102.0.0.15          52      28.0       0.0
# 102.0.0.23          44      28.0       4.0
# 102.0.0.19         108      52.0       0.0
# 102.0.0.3          100      48.0       0.0
# 102.0.0.16          52      36.0       4.0
# 102.0.0.26          32      20.0       0.0
# 102.0.0.14          56      40.0       0.0
# 102.0.0.20          96      44.0      16.0

# %%
normalized_df=(df-df.min())/(df.max()-df.min())
normalized_df = normalized_df.fillna(0)
normalized_df
# Out:
#              first_seen  last_seen  reqs_per_sec  reqs_per_sec_std  total_req  \
# 102.0.0.4      0.000000   0.017589      0.178336          0.218554   0.035577
# 172.20.0.11    0.000589   0.999977      0.010806          0.028424   0.156731
# 172.20.0.12    0.001121   1.000000      0.095675          0.573262   1.000000
# 102.0.0.7      0.033899   0.007303      0.820394          1.000000   0.101923
# 102.0.0.6      0.044939   0.030344      0.073935          0.179816   0.017308
# 102.0.0.9      0.057044   0.000000      1.000000          0.342748   0.044231
# 102.0.0.8      0.094622   0.853794      0.000000          0.024873   0.050000
# 102.0.0.5      0.095917   0.550797      0.000336          0.000000   0.026923
# 102.0.0.10     0.100419   0.001239      0.041173          0.095759   0.000000
# 102.0.0.12     0.134707   0.010516      0.708188          0.592150   0.100000
# 102.0.0.11     0.215516   0.002842      0.095002          0.092738   0.000000
# 102.0.0.2      0.218614   0.134155      0.066910          0.157705   0.101923
# 102.0.0.18     0.255150   0.007262      0.648825          0.413323   0.040385
# 102.0.0.17     0.256731   0.012752      0.435193          0.256097   0.046154
# 102.0.0.13     0.271019   0.017890      0.301595          0.300359   0.046154
# 102.0.0.22     0.298010   1.000000      0.009350          0.094538   0.151923
# 102.0.0.21     0.309171   0.012826      0.199227          0.180839   0.021154
# 102.0.0.24     0.342214   0.003824      0.557283          0.096340   0.005769
# 102.0.0.25     0.353977   0.005616      0.344210          0.300580   0.001923
# 102.0.0.15     0.360985   0.007159      0.258981          0.228350   0.011538
# 102.0.0.23     0.367786   0.006063      0.400398          0.135719   0.007692
# 102.0.0.19     0.371938   0.017582      0.320947          0.420217   0.038462
# 102.0.0.3      1.000000   0.030430      0.401976          0.348271   0.034615
# 102.0.0.16     0.480307   0.009908      0.618837          0.289068   0.011538
# 102.0.0.26     0.489081   0.015400      0.072906          0.068689   0.001923
# 102.0.0.14     0.503499   0.009279      0.309973          0.331407   0.013462
# 102.0.0.20     0.530854   0.011293      0.795608          0.194707   0.032692
#
#              reqs_max  reqs_min
# 102.0.0.4    0.083333      0.00
# 172.20.0.11  0.000000      0.00
# 172.20.0.12  1.000000      0.00
# 102.0.0.7    0.333333      0.00
# 102.0.0.6    0.100000      0.00
# 102.0.0.9    0.150000      0.50
# 102.0.0.8    0.233333      0.00
# 102.0.0.5    0.066667      0.00
# 102.0.0.10   0.016667      0.00
# 102.0.0.12   0.300000      0.00
# 102.0.0.11   0.000000      0.00
# 102.0.0.2    0.166667      0.00
# 102.0.0.18   0.116667      0.00
# 102.0.0.17   0.050000      0.00
# 102.0.0.13   0.083333      0.00
# 102.0.0.22   0.350000      0.00
# 102.0.0.21   0.050000      0.00
# 102.0.0.24   0.016667      0.75
# 102.0.0.25   0.033333      0.00
# 102.0.0.15   0.033333      0.00
# 102.0.0.23   0.033333      0.25
# 102.0.0.19   0.133333      0.00
# 102.0.0.3    0.116667      0.00
# 102.0.0.16   0.066667      0.25
# 102.0.0.26   0.000000      0.00
# 102.0.0.14   0.083333      0.00
# 102.0.0.20   0.100000      1.00

# %%
import math
def ip_to_group(ip):
    if ip.split(".")[0] != '102':
        return -1
    return math.floor((int(ip.split(".")[-1])-2) / 5)
def get_real_label(df):
    data = df.index.values
    result = np.array([ip_to_group(xi) for xi in data])
    return result

# %%
kmeans = KMeans(n_clusters=9, random_state=0)
normalized_df['cluster'] = kmeans.fit_predict(normalized_df)# get centroids
normalized_df['real_label'] = get_real_label(normalized_df)

plt.scatter(normalized_df.first_seen, normalized_df.total_req, c=normalized_df.cluster, alpha = 1, s=10)
# Out:
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn import metrics

# compute cluster purity
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix) 

for c in normalized_df['cluster'].unique():
    selection = normalized_df[normalized_df['cluster'] == c]
    print(selection[['cluster', 'real_label']])
    print(str(c) + ": " + str(purity_score(selection['real_label'], selection['cluster'])))
# Out:
#              cluster  real_label
# 102.0.0.4          2           0
# 172.20.0.11        2          -1
# 102.0.0.6          2           0
# 102.0.0.2          2           0
# 102.0.0.3          2           0
# 2: 0.8
#              cluster  real_label
# 172.20.0.12        8          -1
# 8: 1.0
#             cluster  real_label
# 102.0.0.7         7           1
# 102.0.0.12        7           2
# 7: 0.5
#             cluster  real_label
# 102.0.0.9         6           1
# 102.0.0.10        6           1
# 102.0.0.11        6           1
# 6: 1.0
#            cluster  real_label
# 102.0.0.8        4           1
# 102.0.0.5        4           0
# 4: 0.5
#             cluster  real_label
# 102.0.0.18        0           3
# 102.0.0.17        0           3
# 102.0.0.21        0           3
# 102.0.0.19        0           3
# 0: 1.0
#             cluster  real_label
# 102.0.0.13        1           2
# 102.0.0.15        1           2
# 102.0.0.16        1           2
# 102.0.0.14        1           2
# 1: 1.0
#             cluster  real_label
# 102.0.0.22        3           4
# 102.0.0.25        3           4
# 102.0.0.23        3           4
# 102.0.0.26        3           4
# 3: 1.0
#             cluster  real_label
# 102.0.0.24        5           4
# 102.0.0.20        5           3
# 5: 0.5

# %%
# Cluster and viz dns
# !pip install umap-learn numpy numba
# Dimension reduction and clustering libraries
#import umap.umap_ as umap
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: umap-learn in /home/taylor/.local/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: numpy in /home/taylor/.local/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: numba in /home/taylor/.local/lib/python3.10/site-packages (0.56.4)
# Requirement already satisfied: tqdm in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (4.64.1)
# Requirement already satisfied: scipy>=1.0 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (1.2.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (0.5.8)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/taylor/.local/lib/python3.10/site-packages (from numba) (0.39.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba) (59.6.0)
# Requirement already satisfied: joblib>=0.11 in /home/taylor/.local/lib/python3.10/site-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)

# %%
#normalized_df=(df-df.min())/(df.max()-df.min())
# standard_embedding = umap.UMAP(random_state=42).fit_transform(normalized_df)
# plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=normalized_df.cluster, s=10, cmap='Spectral');

# %%
# Cluster who this
Server_scope
# Out:
# ['data/argus/csv/myMarkovServer0-101.0.0.10.csv',
#  'data/csv/myMarkovServer0-101.0.0.10.csv']

# %%
def hex_col_to_str(df, col):
    df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))

# %%
# Cluster Server resources
## Create ts for each resource
resource_df = format_time_col(scope_to_df(pcap_only(Server_scope)), 'frame.time')
resource_df['frame.time'] = resource_df['frame.time'].apply(lambda x: x+Shadow_offset)
resource_df_filtered = resource_df[(resource_df['http.request'].notna())]
hex_col_to_str(resource_df_filtered, 'tcp.payload')
resource_df_filtered['resource'] = resource_df_filtered['tcp.payload_str'].apply(lambda x: x.split(' ')[1])
resource_df_filtered
# Out:
# /tmp/ipykernel_18483/2636449078.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))
# /tmp/ipykernel_18483/4127982458.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resource_df_filtered['resource'] = resource_df_filtered['tcp.payload_str'].apply(lambda x: x.split(' ')[1])
#       frame.number                 frame.time          ip.src      ip.dst  \
# 6                7 2023-03-20 15:12:58.709103  178.165.72.177  101.0.0.10
# 10              11 2023-03-20 15:12:58.738333   104.244.76.39  101.0.0.10
# 26              27 2023-03-20 15:12:59.324435  178.165.72.177  101.0.0.10
# 30              31 2023-03-20 15:12:59.391305   104.244.76.39  101.0.0.10
# 46              47 2023-03-20 15:12:59.944767  178.165.72.177  101.0.0.10
# ...            ...                        ...             ...         ...
# 6554          6555 2023-03-20 15:16:58.690279   104.244.76.39  101.0.0.10
# 6564          6565 2023-03-20 15:16:59.690279   104.244.76.39  101.0.0.10
# 6574          6575 2023-03-20 15:17:02.635171   104.244.76.39  101.0.0.10
# 6584          6585 2023-03-20 15:17:03.635171   104.244.76.39  101.0.0.10
# 6594          6595 2023-03-20 15:17:04.690279   104.244.76.39  101.0.0.10
#
#       ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
# 6            6        200     200            1            0          NaN  ...
# 10           6        200     200            1            0          NaN  ...
# 26           6        200     200            1            0          NaN  ...
# 30           6        200     200            1            0          NaN  ...
# 46           6        200     200            1            0          NaN  ...
# ...        ...        ...     ...          ...          ...          ...  ...
# 6554         6        200     200            1            0          NaN  ...
# 6564         6        200     200            1            0          NaN  ...
# 6574         6        200     200            1            0          NaN  ...
# 6584         6        200     200            1            0          NaN  ...
# 6594         6        200     200            1            0          NaN  ...
#
#       http.request  udp.port  frame.time_relative  frame.time_delta  \
# 6              1.0       NaN             0.307666          0.197256
# 10             1.0       NaN             0.336896          0.029230
# 26             1.0       NaN             0.922998          0.158616
# 30             1.0       NaN             0.989868          0.066870
# 46             1.0       NaN             1.543330          0.125976
# ...            ...       ...                  ...               ...
# 6554           1.0       NaN           240.288842          0.194116
# 6564           1.0       NaN           241.288842          0.194116
# 6574           1.0       NaN           244.233734          0.157378
# 6584           1.0       NaN           245.233734          0.157378
# 6594           1.0       NaN           246.288842          0.194116
#
#       tcp.time_relative  tcp.time_delta  \
# 6              0.307666        0.206666
# 10             0.327486        0.226486
# 26             0.307666        0.206666
# 30             0.326486        0.225486
# 46             0.312666        0.211666
# ...                 ...             ...
# 6554           0.295116        0.194116
# 6564           0.295116        0.194116
# 6574           0.258378        0.157378
# 6584           0.258378        0.157378
# 6594           0.295116        0.194116
#
#                                             tcp.payload  dns.qry.name  \
# 6     474554202f7265736f75726365302e68746d6c20485454...           NaN
# 10    474554202f7265736f75726365312e68746d6c20485454...           NaN
# 26    474554202f7265736f75726365302e68746d6c20485454...           NaN
# 30    474554202f7265736f75726365312e68746d6c20485454...           NaN
# 46    474554202f7265736f75726365302e68746d6c20485454...           NaN
# ...                                                 ...           ...
# 6554  474554202f7265736f75726365302e68746d6c20485454...           NaN
# 6564  474554202f7265736f75726365302e68746d6c20485454...           NaN
# 6574  474554202f7265736f75726365302e68746d6c20485454...           NaN
# 6584  474554202f7265736f75726365302e68746d6c20485454...           NaN
# 6594  474554202f7265736f75726365302e68746d6c20485454...           NaN
#
#                                         tcp.payload_str         resource
# 6     GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 10    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
# 26    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 30    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
# 46    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# ...                                                 ...              ...
# 6554  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6564  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6574  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6584  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6594  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#
# [656 rows x 61 columns]

# %%
resources = resource_df_filtered['resource'].unique()
flows_re = {}
flows_ts_re = {}
for resource in resources:
    flows_re[resource] = resource_df_filtered[(resource_df_filtered['resource'] == resource)]
    flows_ts_re[resource] = df_to_ts(flows_re[resource].copy()).set_index('frame.time')
# Out:
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()
# /tmp/ipykernel_18483/1356530994.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('1S').sum().rolling(10).sum().dropna().reset_index()

# %%
flows_re
# Out:
# {'/resource0.html':       frame.number                 frame.time          ip.src      ip.dst  \
#  6                7 2023-03-20 15:12:58.709103  178.165.72.177  101.0.0.10
#  26              27 2023-03-20 15:12:59.324435  178.165.72.177  101.0.0.10
#  46              47 2023-03-20 15:12:59.944767  178.165.72.177  101.0.0.10
#  69              70 2023-03-20 15:13:00.560099  178.165.72.177  101.0.0.10
#  73              74 2023-03-20 15:13:00.645171   104.244.76.39  101.0.0.10
#  ...            ...                        ...             ...         ...
#  6554          6555 2023-03-20 15:16:58.690279   104.244.76.39  101.0.0.10
#  6564          6565 2023-03-20 15:16:59.690279   104.244.76.39  101.0.0.10
#  6574          6575 2023-03-20 15:17:02.635171   104.244.76.39  101.0.0.10
#  6584          6585 2023-03-20 15:17:03.635171   104.244.76.39  101.0.0.10
#  6594          6595 2023-03-20 15:17:04.690279   104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  6            6        200     200            1            0          NaN  ...
#  26           6        200     200            1            0          NaN  ...
#  46           6        200     200            1            0          NaN  ...
#  69           6        200     200            1            0          NaN  ...
#  73           6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  6554         6        200     200            1            0          NaN  ...
#  6564         6        200     200            1            0          NaN  ...
#  6574         6        200     200            1            0          NaN  ...
#  6584         6        200     200            1            0          NaN  ...
#  6594         6        200     200            1            0          NaN  ...
#
#        http.request  udp.port  frame.time_relative  frame.time_delta  \
#  6              1.0       NaN             0.307666          0.197256
#  26             1.0       NaN             0.922998          0.158616
#  46             1.0       NaN             1.543330          0.125976
#  69             1.0       NaN             2.158662          0.082306
#  73             1.0       NaN             2.243734          0.085072
#  ...            ...       ...                  ...               ...
#  6554           1.0       NaN           240.288842          0.194116
#  6564           1.0       NaN           241.288842          0.194116
#  6574           1.0       NaN           244.233734          0.157378
#  6584           1.0       NaN           245.233734          0.157378
#  6594           1.0       NaN           246.288842          0.194116
#
#        tcp.time_relative  tcp.time_delta  \
#  6              0.307666        0.206666
#  26             0.307666        0.206666
#  46             0.312666        0.211666
#  69             0.307666        0.206666
#  73             0.268378        0.167378
#  ...                 ...             ...
#  6554           0.295116        0.194116
#  6564           0.295116        0.194116
#  6574           0.258378        0.157378
#  6584           0.258378        0.157378
#  6594           0.295116        0.194116
#
#                                              tcp.payload  dns.qry.name  \
#  6     474554202f7265736f75726365302e68746d6c20485454...           NaN
#  26    474554202f7265736f75726365302e68746d6c20485454...           NaN
#  46    474554202f7265736f75726365302e68746d6c20485454...           NaN
#  69    474554202f7265736f75726365302e68746d6c20485454...           NaN
#  73    474554202f7265736f75726365302e68746d6c20485454...           NaN
#  ...                                                 ...           ...
#  6554  474554202f7265736f75726365302e68746d6c20485454...           NaN
#  6564  474554202f7265736f75726365302e68746d6c20485454...           NaN
#  6574  474554202f7265736f75726365302e68746d6c20485454...           NaN
#  6584  474554202f7265736f75726365302e68746d6c20485454...           NaN
#  6594  474554202f7265736f75726365302e68746d6c20485454...           NaN
#
#                                          tcp.payload_str         resource
#  6     GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  26    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  46    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  69    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  73    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  ...                                                 ...              ...
#  6554  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  6564  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  6574  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  6584  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#  6594  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#
#  [145 rows x 61 columns],
#  '/resource1.html':       frame.number                 frame.time         ip.src      ip.dst  \
#  10              11 2023-03-20 15:12:58.738333  104.244.76.39  101.0.0.10
#  30              31 2023-03-20 15:12:59.391305  104.244.76.39  101.0.0.10
#  50              51 2023-03-20 15:13:00.044277  104.244.76.39  101.0.0.10
#  80              81 2023-03-20 15:13:00.698249  104.244.76.39  101.0.0.10
#  103            104 2023-03-20 15:13:01.351221  104.244.76.39  101.0.0.10
#  ...            ...                        ...            ...         ...
#  4647          4648 2023-03-20 15:14:24.737333  104.244.76.39  101.0.0.10
#  4760          4761 2023-03-20 15:14:26.047277  104.244.76.39  101.0.0.10
#  4791          4792 2023-03-20 15:14:26.712249  104.244.76.39  101.0.0.10
#  4897          4898 2023-03-20 15:14:28.737334  104.244.76.39  101.0.0.10
#  5497          5498 2023-03-20 15:14:44.635171  104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  10           6        200     200            1            0          NaN  ...
#  30           6        200     200            1            0          NaN  ...
#  50           6        200     200            1            0          NaN  ...
#  80           6        200     200            1            0          NaN  ...
#  103          6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  4647         6        200     200            1            0          NaN  ...
#  4760         6        200     200            1            0          NaN  ...
#  4791         6        200     200            1            0          NaN  ...
#  4897         6        200     200            1            0          NaN  ...
#  5497         6        200     200            1            0          NaN  ...
#
#        http.request  udp.port  frame.time_relative  frame.time_delta  \
#  10             1.0       NaN             0.336896          0.029230
#  30             1.0       NaN             0.989868          0.066870
#  50             1.0       NaN             1.642840          0.099510
#  80             1.0       NaN             2.296812          0.038150
#  103            1.0       NaN             2.949784          0.075790
#  ...            ...       ...                  ...               ...
#  4647           1.0       NaN            86.335896          0.062768
#  4760           1.0       NaN            87.645840          0.052728
#  4791           1.0       NaN            88.310812          0.043566
#  4897           1.0       NaN            90.335897          0.002162
#  5497           1.0       NaN           106.233734          0.148377
#
#        tcp.time_relative  tcp.time_delta  \
#  10             0.327486        0.226486
#  30             0.326486        0.225486
#  50             0.326486        0.225486
#  80             0.326486        0.225486
#  103            0.326486        0.225486
#  ...                 ...             ...
#  4647           0.326486        0.225486
#  4760           0.326486        0.225486
#  4791           0.332486        0.231486
#  4897           0.326486        0.225486
#  5497           0.258378        0.157378
#
#                                              tcp.payload  dns.qry.name  \
#  10    474554202f7265736f75726365312e68746d6c20485454...           NaN
#  30    474554202f7265736f75726365312e68746d6c20485454...           NaN
#  50    474554202f7265736f75726365312e68746d6c20485454...           NaN
#  80    474554202f7265736f75726365312e68746d6c20485454...           NaN
#  103   474554202f7265736f75726365312e68746d6c20485454...           NaN
#  ...                                                 ...           ...
#  4647  474554202f7265736f75726365312e68746d6c20485454...           NaN
#  4760  474554202f7265736f75726365312e68746d6c20485454...           NaN
#  4791  474554202f7265736f75726365312e68746d6c20485454...           NaN
#  4897  474554202f7265736f75726365312e68746d6c20485454...           NaN
#  5497  474554202f7265736f75726365312e68746d6c20485454...           NaN
#
#                                          tcp.payload_str         resource
#  10    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  30    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  50    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  80    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  103   GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  ...                                                 ...              ...
#  4647  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  4760  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  4791  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  4897  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  5497  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#
#  [134 rows x 61 columns],
#  '/resource2.html':       frame.number                 frame.time          ip.src      ip.dst  \
#  773            774 2023-03-20 15:13:16.697809  178.165.72.177  101.0.0.10
#  812            813 2023-03-20 15:13:17.286749  178.165.72.177  101.0.0.10
#  865            866 2023-03-20 15:13:17.873689  178.165.72.177  101.0.0.10
#  909            910 2023-03-20 15:13:18.693810  178.165.72.177  101.0.0.10
#  960            961 2023-03-20 15:13:19.309750  178.165.72.177  101.0.0.10
#  ...            ...                        ...             ...         ...
#  5544          5545 2023-03-20 15:14:46.690278   104.244.76.39  101.0.0.10
#  5578          5579 2023-03-20 15:14:49.687810  178.165.72.177  101.0.0.10
#  5601          5602 2023-03-20 15:14:51.690278   104.244.76.39  101.0.0.10
#  5984          5985 2023-03-20 15:15:35.690278   104.244.76.39  101.0.0.10
#  6034          6035 2023-03-20 15:15:39.700277   104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  773          6        200     200            1            0          NaN  ...
#  812          6        200     200            1            0          NaN  ...
#  865          6        200     200            1            0          NaN  ...
#  909          6        200     200            1            0          NaN  ...
#  960          6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  5544         6        200     200            1            0          NaN  ...
#  5578         6        200     200            1            0          NaN  ...
#  5601         6        200     200            1            0          NaN  ...
#  5984         6        200     200            1            0          NaN  ...
#  6034         6        200     200            1            0          NaN  ...
#
#        http.request  udp.port  frame.time_relative  frame.time_delta  \
#  773            1.0       NaN            18.296372          0.024125
#  812            1.0       NaN            18.885312          0.070405
#  865            1.0       NaN            19.472252          0.004373
#  909            1.0       NaN            20.292373          0.058639
#  960            1.0       NaN            20.908313          0.016240
#  ...            ...       ...                  ...               ...
#  5544           1.0       NaN           108.288841          0.194116
#  5578           1.0       NaN           111.286373          0.043638
#  5601           1.0       NaN           113.288841          0.055107
#  5984           1.0       NaN           157.288841          0.194116
#  6034           1.0       NaN           161.298840          0.194116
#
#        tcp.time_relative  tcp.time_delta  \
#  773            0.303470        0.202470
#  812            0.293470        0.192470
#  865            0.293470        0.192470
#  909            0.299470        0.198470
#  960            0.301470        0.200470
#  ...                 ...             ...
#  5544           0.295116        0.194116
#  5578           0.293470        0.192470
#  5601           0.295116        0.194116
#  5984           0.295116        0.194116
#  6034           0.295116        0.194116
#
#                                              tcp.payload  dns.qry.name  \
#  773   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  812   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  865   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  909   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  960   474554202f7265736f75726365322e68746d6c20485454...           NaN
#  ...                                                 ...           ...
#  5544  474554202f7265736f75726365322e68746d6c20485454...           NaN
#  5578  474554202f7265736f75726365322e68746d6c20485454...           NaN
#  5601  474554202f7265736f75726365322e68746d6c20485454...           NaN
#  5984  474554202f7265736f75726365322e68746d6c20485454...           NaN
#  6034  474554202f7265736f75726365322e68746d6c20485454...           NaN
#
#                                          tcp.payload_str         resource
#  773   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  812   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  865   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  909   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  960   GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  ...                                                 ...              ...
#  5544  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  5578  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  5601  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  5984  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#  6034  GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#
#  [130 rows x 61 columns],
#  '/resource3.html':       frame.number                 frame.time         ip.src      ip.dst  \
#  1702          1703 2023-03-20 15:13:37.635171  104.244.76.39  101.0.0.10
#  1710          1711 2023-03-20 15:13:37.690278  104.244.76.39  101.0.0.10
#  1755          1756 2023-03-20 15:13:38.644172  104.244.76.39  101.0.0.10
#  1759          1760 2023-03-20 15:13:38.690278  104.244.76.39  101.0.0.10
#  1799          1800 2023-03-20 15:13:39.160928  104.244.76.39  101.0.0.10
#  ...            ...                        ...            ...         ...
#  5737          5738 2023-03-20 15:15:04.635171  104.244.76.39  101.0.0.10
#  5741          5742 2023-03-20 15:15:04.644172  104.244.76.39  101.0.0.10
#  5754          5755 2023-03-20 15:15:05.160928  104.244.76.39  101.0.0.10
#  5764          5765 2023-03-20 15:15:05.677684  104.244.76.39  101.0.0.10
#  6011          6012 2023-03-20 15:15:37.635171  104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  1702         6        200     200            1            0          NaN  ...
#  1710         6        200     200            1            0          NaN  ...
#  1755         6        200     200            1            0          NaN  ...
#  1759         6        200     200            1            0          NaN  ...
#  1799         6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  5737         6        200     200            1            0          NaN  ...
#  5741         6        200     200            1            0          NaN  ...
#  5754         6        200     200            1            0          NaN  ...
#  5764         6        200     200            1            0          NaN  ...
#  6011         6        200     200            1            0          NaN  ...
#
#        http.request  udp.port  frame.time_relative  frame.time_delta  \
#  1702           1.0       NaN            39.233734          0.132734
#  1710           1.0       NaN            39.288841          0.046106
#  1755           1.0       NaN            40.242735          0.116866
#  1759           1.0       NaN            40.288841          0.046106
#  1799           1.0       NaN            40.759491          0.073534
#  ...            ...       ...                  ...               ...
#  5737           1.0       NaN           126.233734          0.148377
#  5741           1.0       NaN           126.242735          0.009001
#  5754           1.0       NaN           126.759491          0.157378
#  5764           1.0       NaN           127.276247          0.157378
#  6011           1.0       NaN           159.233734          0.000000
#
#        tcp.time_relative  tcp.time_delta  \
#  1702           0.258378        0.157378
#  1710           0.295116        0.194116
#  1755           0.258378        0.157378
#  1759           0.295116        0.194116
#  1799           0.258378        0.157378
#  ...                 ...             ...
#  5737           0.258378        0.157378
#  5741           0.258378        0.157378
#  5754           0.258378        0.157378
#  5764           0.258378        0.157378
#  6011           0.258378        0.157378
#
#                                              tcp.payload  dns.qry.name  \
#  1702  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  1710  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  1755  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  1759  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  1799  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  ...                                                 ...           ...
#  5737  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  5741  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  5754  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  5764  474554202f7265736f75726365332e68746d6c20485454...           NaN
#  6011  474554202f7265736f75726365332e68746d6c20485454...           NaN
#
#                                          tcp.payload_str         resource
#  1702  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1710  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1755  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1759  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1799  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  ...                                                 ...              ...
#  5737  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  5741  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  5754  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  5764  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  6011  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#
#  [128 rows x 61 columns],
#  '/resource4.html':       frame.number                 frame.time         ip.src      ip.dst  \
#  1975          1976 2023-03-20 15:13:44.635171  104.244.76.39  101.0.0.10
#  2080          2081 2023-03-20 15:13:46.644172  104.244.76.39  101.0.0.10
#  2103          2104 2023-03-20 15:13:47.163928  104.244.76.39  101.0.0.10
#  2130          2131 2023-03-20 15:13:47.681684  104.244.76.39  101.0.0.10
#  2160          2161 2023-03-20 15:13:48.198440  104.244.76.39  101.0.0.10
#  ...            ...                        ...            ...         ...
#  5964          5965 2023-03-20 15:15:31.668683  104.244.76.39  101.0.0.10
#  5974          5975 2023-03-20 15:15:32.635171  104.244.76.39  101.0.0.10
#  5994          5995 2023-03-20 15:15:36.635172  104.244.76.39  101.0.0.10
#  6010          6011 2023-03-20 15:15:37.635171  104.244.76.39  101.0.0.10
#  6044          6045 2023-03-20 15:15:43.635172  104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  1975         6        200     200            1            0          NaN  ...
#  2080         6        200     200            1            0          NaN  ...
#  2103         6        200     200            1            0          NaN  ...
#  2130         6        200     200            1            0          NaN  ...
#  2160         6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  5964         6        200     200            1            0          NaN  ...
#  5974         6        200     200            1            0          NaN  ...
#  5994         6        200     200            1            0          NaN  ...
#  6010         6        200     200            1            0          NaN  ...
#  6044         6        200     200            1            0          NaN  ...
#
#        http.request  udp.port  frame.time_relative  frame.time_delta  \
#  1975           1.0       NaN            46.233734          0.139009
#  2080           1.0       NaN            48.242735          0.009001
#  2103           1.0       NaN            48.762491          0.157378
#  2130           1.0       NaN            49.280247          0.046513
#  2160           1.0       NaN            49.797003          0.046513
#  ...            ...       ...                  ...               ...
#  5964           1.0       NaN           153.267246          0.157378
#  5974           1.0       NaN           154.233734          0.157378
#  5994           1.0       NaN           158.233735          0.157378
#  6010           1.0       NaN           159.233734          0.132734
#  6044           1.0       NaN           165.233735          0.157378
#
#        tcp.time_relative  tcp.time_delta  \
#  1975           0.258378        0.157378
#  2080           0.258378        0.157378
#  2103           0.258378        0.157378
#  2130           0.259378        0.158378
#  2160           0.258378        0.157378
#  ...                 ...             ...
#  5964           0.258378        0.157378
#  5974           0.258378        0.157378
#  5994           0.258378        0.157378
#  6010           0.258378        0.157378
#  6044           0.258378        0.157378
#
#                                              tcp.payload  dns.qry.name  \
#  1975  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  2080  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  2103  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  2130  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  2160  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  ...                                                 ...           ...
#  5964  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  5974  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  5994  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  6010  474554202f7265736f75726365342e68746d6c20485454...           NaN
#  6044  474554202f7265736f75726365342e68746d6c20485454...           NaN
#
#                                          tcp.payload_str         resource
#  1975  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2080  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2103  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2130  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2160  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  ...                                                 ...              ...
#  5964  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  5974  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  5994  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  6010  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  6044  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#
#  [119 rows x 61 columns]}

# %%
import numpy as np
def generate_features_resource(df, flow):
    features = []
    # 'first_seen'
    #features += [float(df['frame.time'].min().timestamp())]
    features += [df['frame.time'].min()]
    # 'last_seen'
    #features += [float(df['frame.time'].max().timestamp())]
    features += [df['frame.time'].max()]
    # 'reqs_per_sec'
    features += [flow['count'].mean()]
    # 'reqs_per_sec_std'
    val = flow['count'].std()
    features += [0 if np.isnan(val) else val]
    # 'total_req'
    features += [len(df)]
    # 'reqs_max'
    features += [flow['count'].max()]
    # 'reqs_min'
    features += [flow['count'].min()]
    return [features]
## Get flow features
cols = ['first_seen','last_seen', 'reqs_per_sec', 'reqs_per_sec_std', 'total_req', 'reqs_max', 'reqs_min']
index = []
feature_data = []
for ip in flows_re:
    index += [ip]
    feature_data += generate_features_resource(flows_re[ip], flows_ts_re[ip])

  
# Create the pandas DataFrame
df_resource = pd.DataFrame(feature_data, columns=cols, index=index)
df_resource
# Out:
#                                 first_seen                  last_seen  \
# /resource0.html 2023-03-20 15:12:58.709103 2023-03-20 15:17:04.690279
# /resource1.html 2023-03-20 15:12:58.738333 2023-03-20 15:14:44.635171
# /resource2.html 2023-03-20 15:13:16.697809 2023-03-20 15:15:39.700277
# /resource3.html 2023-03-20 15:13:37.635171 2023-03-20 15:15:37.635171
# /resource4.html 2023-03-20 15:13:44.635171 2023-03-20 15:15:43.635172
#
#                  reqs_per_sec  reqs_per_sec_std  total_req  reqs_max  reqs_min
# /resource0.html      5.676471          5.595390        145      22.0       0.0
# /resource1.html     12.948980         12.192082        134      41.0       0.0
# /resource2.html      9.029630          8.751069        130      28.0       0.0
# /resource3.html     10.517857          7.601543        128      26.0       0.0
# /resource4.html     10.189189          9.348324        119      31.0       0.0

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

for f in flows_ts_re:
    flows_ts_re[f]['count'].plot(label=f)
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
  
# adding legend to the curve
plt.legend()

# %%
# Link
# Which group has what signal
cluser_col_name = 'cluster' # 'real_label'

groups = normalized_df[cluser_col_name].unique()
dtypes = list(flows_ts_ip.values())[0].dtypes.to_dict()
cols = list(list(flows_ts_ip.values())[0].columns)
sum_ts = {}
for group in groups:
    sum_ts[group] = pd.DataFrame(columns=cols)
    sum_ts[group].astype(dtypes)
    #sum_ts[group].set_index('frame.time')
for ip in normalized_df.index.tolist():
    s = flows_ts_ip[ip].add(sum_ts[normalized_df.loc[ip][cluser_col_name]], fill_value=0)
    sum_ts[normalized_df.loc[ip][cluser_col_name]] = s

# %%
# normalize ts

# %%
# resource_and_groups = sum_ts + flows_ts_re
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

limit = 300

for f in flows_ts_re:
     flows_ts_re[f]['count'].head(limit).plot(label=f)
for f in sum_ts:
    #print(min(sum_ts[f].index.values)  - (10 * 1000000000))
    if f == -1: # Don't plot resolver
        continue
    sum_ts[f]['count'].div(4).head(limit).plot(label=f)
    
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
plt.ylabel('Packets (scaled)')
  
# adding legend to the curve
plt.legend()

# %%
# Find mathing groups for resources
# !pip install pyts

from pyts.metrics import dtw, itakura_parallelogram, sakoe_chiba_band
from pyts.metrics.dtw import (cost_matrix, accumulated_cost_matrix,
                              _return_path, _blurred_path_region)

def compare_ts(ts1, ts2):
    dtw_classic, path_classic = dtw(ts1, ts2, dist='square',
                                method='classic', return_path=True)
    return dtw_classic

def normalize_ts(ts):
    ts=(ts-ts.min())/(ts.max()-ts.min())
    return ts.fillna(0)

def compare_ts_reshape(ts1, ts2):
    ts1_norm = ts1.copy(deep=True)
    ts2_norm = ts2.copy(deep=True)
    
    buffer_room = 30 # in seconds
    delay = 120
    
    # lock to same range with buffer room on each side to account for network (or PPT) delay
    start = min(ts1.index.values) + (delay * 1000000000) - (buffer_room * 1000000000)
    end = max(ts1.index.values) + (buffer_room * 1000000000)+ (delay * 1000000000)
#     print("start: " + str(start))
#     print("end: " + str(end))
    #print(end - start)
    
#     ts1_norm = ts1_norm[start:end]
    ts2_norm = ts2_norm[start:end]
   # print(len(ts2_norm))
    
    # detect if no overlap
    if len(ts1_norm) < 2 or len(ts2_norm) < 2:
        return float("inf")
    
    # Normalize peaks?
    ts1_norm = normalize_ts(ts1_norm)
    ts2_norm = normalize_ts(ts2_norm)

    return compare_ts(ts1_norm, ts2_norm)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyts in /home/taylor/.local/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: scipy>=1.3.0 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.10.1)
# Requirement already satisfied: joblib>=0.12 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.2.0)
# Requirement already satisfied: numba>=0.48.0 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (0.56.4)
# Requirement already satisfied: numpy>=1.17.5 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22.1 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.2.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba>=0.48.0->pyts) (59.6.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/taylor/.local/lib/python3.10/site-packages (from numba>=0.48.0->pyts) (0.39.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn>=0.22.1->pyts) (3.1.0)

# %%
answer = {'/resource0.html': 0, '/resource1.html': 1, '/resource2.html': 2, '/resource3.html': 3, '/resource4.html': 4}
num_correct = 0.0
for f in flows_ts_re:
    print(f)
    best_group = -1
    best_sim = -1
    for c in sum_ts:
        if len(sum_ts[c]['count']) < 2:
            print("\tGroup " + str(c) + " is too short. Skipping")
            continue
        sim = compare_ts_reshape(flows_ts_re[f]['count'], sum_ts[c]['count'].div(1))
        print("\tGroup " + str(c) + "\t\tSim:" + str(sim))
        if best_group == -1 or best_sim > sim:
            best_group = c
            best_sim = sim
    print("\n\tBest match is group " + str(best_group) + " with sim " + str(best_sim))
    if answer[f] == best_group:
        print('Correct!\n\n')
        num_correct += 1
print(str(num_correct/len(answer) *100) + "% Correct")
# Out:
# /resource0.html
# 	Group 2		Sim:1.5109805103000329
# 	Group 8		Sim:2.4103724503499135
# 	Group 7		Sim:1.2820724728064339
# 	Group 6		Sim:2.4577900633043197
# 	Group 4		Sim:2.314656045537556
# 	Group 0		Sim:2.6339338586767442
# 	Group 1		Sim:2.291359035331463
# 	Group 3		Sim:2.7186733111947743
# 	Group 5		Sim:2.5827973095364576
#
# 	Best match is group 7 with sim 1.2820724728064339
# /resource1.html
# 	Group 2		Sim:1.2882230062976983
# 	Group 8		Sim:1.498271666434352
# 	Group 7		Sim:1.8687186304802352
# 	Group 6		Sim:1.041525210239273
# 	Group 4		Sim:0.8887328646243088
# 	Group 0		Sim:0.8924940610640143
# 	Group 1		Sim:2.269895829608475
# 	Group 3		Sim:0.9020373037552649
# 	Group 5		Sim:2.466616037365407
#
# 	Best match is group 4 with sim 0.8887328646243088
# /resource2.html
# 	Group 2		Sim:2.313213144403702
# 	Group 8		Sim:1.198331142031065
# 	Group 7		Sim:1.139923305296285
# 	Group 6		Sim:1.6237239888099027
# 	Group 4		Sim:2.058526437228707
# 	Group 0		Sim:0.9905937708129784
# 	Group 1		Sim:1.3653695941225836
# 	Group 3		Sim:1.3586350944662413
# 	Group 5		Sim:2.6964285714285716
#
# 	Best match is group 0 with sim 0.9905937708129784
# /resource3.html
# 	Group 2		Sim:2.4064220146947357
# 	Group 8		Sim:0.8474876333520985
# 	Group 7		Sim:2.07276346166819
# 	Group 6		Sim:1.1039375774797597
# 	Group 4		Sim:1.415684753102144
# 	Group 0		Sim:0.763989317409354
# 	Group 1		Sim:2.6080134528733363
# 	Group 3		Sim:1.152247485670378
# 	Group 5		Sim:2.7725507609227806
#
# 	Best match is group 0 with sim 0.763989317409354
# /resource4.html
# 	Group 2		Sim:2.236161638512341
# 	Group 8		Sim:0.6052149367514105
# 	Group 7		Sim:1.8578147871302393
# 	Group 6		Sim:1.113046066361789
# 	Group 4		Sim:1.8052002591927385
# 	Group 0		Sim:0.8794449335904917
# 	Group 1		Sim:1.7215803872125701
# 	Group 3		Sim:0.6025691296828137
# 	Group 5		Sim:2.38612597412879
#
# 	Best match is group 3 with sim 0.6025691296828137
# 0.0% Correct
