# Get argus data
arguspath = "data/argus/csv/"
argusCSVs = getFilenames(arguspath)

# Get pcap data
pcappath = "data/csv/"
pcapCSVs = getFilenames(pcappath)
data = argusCSVs + pcapCSVs

# %%
import pandas as pd

# %%
df = pd.read_csv (pcapCSVs[0])
df
# Out:
#        frame.number                           frame.time     ip.src  \
# 0                 1  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 1                 2  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 2                 3  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 3                 4  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# 4                 5  Dec 31, 1969 19:04:01.000000000 EST  127.0.0.1
# ...             ...                                  ...        ...
# 16311         16312  Dec 31, 1969 19:59:58.496652000 EST  127.0.0.1
# 16312         16313  Dec 31, 1969 19:59:59.491652000 EST  127.0.0.1
# 16313         16314  Dec 31, 1969 19:59:59.491652000 EST  127.0.0.1
# 16314         16315  Dec 31, 1969 19:59:59.496652000 EST  127.0.0.1
# 16315         16316  Dec 31, 1969 19:59:59.496652000 EST  127.0.0.1
#
#           ip.dst  ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  \
# 0      127.0.0.1         6         40      40            1            0
# 1      127.0.0.1         6         40      40            1            0
# 2      127.0.0.1         6         40      40            1            0
# 3      127.0.0.1         6         40      40            1            0
# 4      127.0.0.1         6         65      65            1            0
# ...          ...       ...        ...     ...          ...          ...
# 16311  127.0.0.1         6         40      40            1            0
# 16312  127.0.0.1         6         53      53            1            0
# 16313  127.0.0.1         6         53      53            1            0
# 16314  127.0.0.1         6         40      40            1            0
# 16315  127.0.0.1         6         40      40            1            0
#
#        ip.fragment  ...  dtls.handshake.extensions_alpn_str  \
# 0              NaN  ...                                 NaN
# 1              NaN  ...                                 NaN
# 2              NaN  ...                                 NaN
# 3              NaN  ...                                 NaN
# 4              NaN  ...                                 NaN
# ...            ...  ...                                 ...
# 16311          NaN  ...                                 NaN
# 16312          NaN  ...                                 NaN
# 16313          NaN  ...                                 NaN
# 16314          NaN  ...                                 NaN
# 16315          NaN  ...                                 NaN
#
#        dtls.handshake.extensions_alpn_str_len  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 16311                                     NaN
# 16312                                     NaN
# 16313                                     NaN
# 16314                                     NaN
# 16315                                     NaN
#
#        dtls.handshake.extensions_key_share_client_length  http.request  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 16311                                                NaN           NaN
# 16312                                                NaN           NaN
# 16313                                                NaN           NaN
# 16314                                                NaN           NaN
# 16315                                                NaN           NaN
#
#        udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
# 0           NaN             0.000000             0.000           0.000000
# 1           NaN             0.000000             0.000           0.000000
# 2           NaN             0.000000             0.000           0.000000
# 3           NaN             0.000000             0.000           0.000000
# 4           NaN             0.000000             0.000           0.000000
# ...         ...                  ...               ...                ...
# 16311       NaN          3357.496652             0.000        3357.496652
# 16312       NaN          3358.491652             0.995        3358.491652
# 16313       NaN          3358.491652             0.000        3358.491652
# 16314       NaN          3358.496652             0.005        3358.496652
# 16315       NaN          3358.496652             0.000        3358.496652
#
#        tcp.time_delta                                        tcp.payload
# 0               0.000                                                NaN
# 1               0.000                                                NaN
# 2               0.000                                                NaN
# 3               0.000                                                NaN
# 4               0.000  41555448454e544943415445202270617373776f726422...
# ...               ...                                                ...
# 16311           0.000                                                NaN
# 16312           0.995                         36353020425720302031330d0a
# 16313           0.000                         36353020425720302031330d0a
# 16314           0.005                                                NaN
# 16315           0.000                                                NaN
#
# [16316 rows x 58 columns]

# %%
len(data)
# Out:
# 148

# %%
len(argusCSVs)
# Out:
# 74

# %%
# Basic Scopes
import re

# Get all clients and ISP dns scope
r = re.compile(".*isp.csv|.*Client[0-9]*-(?!127\.0\.0\.1)[0-9]*.[0-9]*.[0-9]*.[0-9]*..csv")
ISP_scope = list(filter(r.match, data))

# Access to public resolver scope
r = re.compile(".*isp.csv")
Access_resolver = list(filter(r.match, data))

# DNS Scope
r = re.compile("(.*tld|.*root-server|.*sld).csv")
Access_to_auth_zone = list(filter(r.match, data))

# Access Tor Scope
r = re.compile(".*Client[0-9]*-(?!127\.0\.0\.1)[0-9]*.[0-9]*.[0-9]*.[0-9]*..csv")
Access_tor = list(filter(r.match, data))

# Server Public Scope
r = re.compile(".*myMarkovServer0*-(?!127\.0\.0\.1)[0-9]*\.[0-9]*\.[0-9]*\.[0-9]*.csv")
Server_scope = list(filter(r.match, data))

# tor Exit scope
r = re.compile(".*exit.*")
Tor_exit_Scope = list(filter(r.match, data))

# tor Guard scope
r = re.compile(".*guard.*")
Tor_guard_Scope = list(filter(r.match, data))

# tor Relay scope
r = re.compile(".*relay.*")
Tor_relay_Scope = list(filter(r.match, data))

# tor Middle scope
r = re.compile(".*middle.*")
Tor_middle_Scope = list(filter(r.match, data))

# tor 4uthority scope
r = re.compile(".*4uthority.*")
Tor_4uthority_Scope = list(filter(r.match, data))

# resolver scope
r = re.compile(".*resolver.*")
resolver_Scope = list(filter(r.match, data))

# %%
def pcap_only(lis):
    r = re.compile(".*data/csv.*")
    return list(filter(r.match, lis))

def format_time_col(df, time_col):
    time_format='%b %d, %Y %X.%f'
    df[time_col] = df[time_col].apply(lambda x: datetime.strptime(x[:-7], time_format))
    df.set_index(time_col)
    return df

def scope_to_df(scope):
    df = pd.DataFrame()
    for f in scope:
        ddf = pd.read_csv (f)
        df = pd.concat([df, ddf])
    return df

# %%
from datetime import datetime

def df_to_ts(df):
    df['count'] = 1
    return df.set_index('frame.time').resample('T').sum().dropna().reset_index()

# %%
# get start time for GNS3
GNS3_data = format_time_col(scope_to_df(pcap_only(Access_resolver + Access_to_auth_zone)), 'frame.time')
GNS3_starttime = GNS3_data.head(1)['frame.time'].tolist()[0]
Shadow_starttime = datetime.strptime('Dec 31, 1969 19:30:00', '%b %d, %Y %X')
Shadow_offset = GNS3_starttime - Shadow_starttime
Shadow_offset
# Out:
# Timedelta('19436 days 19:42:58.247604')

# %%
dns_df = format_time_col(scope_to_df(pcap_only(Access_to_auth_zone)), 'frame.time')

# %%
# Steps
# Who do this
# Cluster of who this
# Cluster per scope? all scopes?
# Link Clusters

# %%
# Assume range is whole experiment
# Justification: Looking for first group and all groups at same time (30 minute range, In future should have comms
# going on that start before we are looking [noise])

# %%
# Cluster DNS
## Create ts for each IP
resolv_df = format_time_col(scope_to_df(pcap_only(resolver_Scope)), 'frame.time')
DNS_PROTO = 17.0
resolv_df_filtered = resolv_df[resolv_df['ip.proto'] == DNS_PROTO]
IPs = resolv_df_filtered['ip.src'].unique()
flows_ip = {}
flows_ts_ip = {}
resolver_ip = '192.168.150.10'
for ip in IPs:
    if ip != resolver_ip:
        flows_ip[ip] = resolv_df_filtered[(resolv_df_filtered['ip.dst'] == ip) | (resolv_df_filtered['ip.src'] == ip)]
        flows_ts_ip[ip] = df_to_ts(flows_ip[ip].copy()).set_index('frame.time')
# Out:
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()

# %%
flows_ts_ip
# Out:
# {'102.0.0.4':                      frame.number  ip.proto  frame.len  ip.len  ip.flags.df  \
#  frame.time
#  2023-03-20 15:14:00         13346     714.0       3702  3114.0         21.0
#  2023-03-20 15:15:00         96624     680.0       3550  2990.0         20.0
#  2023-03-20 15:16:00        195000     340.0       1811  1531.0         10.0
#  2023-03-20 15:17:00        105672     136.0        730   618.0          4.0
#  2023-03-20 15:18:00             0       0.0          0     0.0          0.0
#  ...                           ...       ...        ...     ...          ...
#  2023-03-20 16:52:00        573596     136.0        719   607.0          4.0
#  2023-03-20 16:53:00             0       0.0          0     0.0          0.0
#  2023-03-20 16:54:00        291234      68.0        380   324.0          2.0
#  2023-03-20 16:55:00             0       0.0          0     0.0          0.0
#  2023-03-20 16:56:00        294646      68.0        360   304.0          2.0
#
#                       ip.flags.mf  ip.fragment  ip.fragment.count  \
#  frame.time
#  2023-03-20 15:14:00          0.0          0.0                0.0
#  2023-03-20 15:15:00          0.0          0.0                0.0
#  2023-03-20 15:16:00          0.0          0.0                0.0
#  2023-03-20 15:17:00          0.0          0.0                0.0
#  2023-03-20 15:18:00          0.0          0.0                0.0
#  ...                          ...          ...                ...
#  2023-03-20 16:52:00          0.0          0.0                0.0
#  2023-03-20 16:53:00          0.0          0.0                0.0
#  2023-03-20 16:54:00          0.0          0.0                0.0
#  2023-03-20 16:55:00          0.0          0.0                0.0
#  2023-03-20 16:56:00          0.0          0.0                0.0
#
#                       ip.fragments  ip.ttl  ...  \
#  frame.time                                 ...
#  2023-03-20 15:14:00           0.0  2667.0  ...
#  2023-03-20 15:15:00           0.0  2540.0  ...
#  2023-03-20 15:16:00           0.0  1270.0  ...
#  2023-03-20 15:17:00           0.0   508.0  ...
#  2023-03-20 15:18:00           0.0     0.0  ...
#  ...                           ...     ...  ...
#  2023-03-20 16:52:00           0.0   508.0  ...
#  2023-03-20 16:53:00           0.0     0.0  ...
#  2023-03-20 16:54:00           0.0   254.0  ...
#  2023-03-20 16:55:00           0.0     0.0  ...
#  2023-03-20 16:56:00           0.0   254.0  ...
#
#                       dtls.handshake.extensions_alpn_str_len  \
#  frame.time
#  2023-03-20 15:14:00                                     0.0
# images in the notebook
# %matplotlib inline

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

for f in flows_ts_ip:
    flows_ts_ip[f]['count'].plot(label=f)
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
  
# adding legend to the curve
plt.legend()

# %%
# !pip install scikit-learn
from sklearn.cluster import KMeans
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/taylor/.local/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn) (1.10.1)

# %%
def generate_features(df, flow):
    features = []
    # 'first_seen'
    features += [float(df['frame.time'].min().timestamp())]
    # 'last_seen'
    features += [float(df['frame.time'].max().timestamp())]
    # 'reqs_per_sec'
    features += [flow['count'].mean()]
    # 'reqs_per_sec_std'
    val = flow['count'].std()
    features += [0 if np.isnan(val) else val]
    # 'total_req'
    features += [len(df)]
    # 'reqs_max'
    features += [flow['count'].max()]
    # 'reqs_min'
    features += [flow['count'].min()]
    return [features]
## Get flow features
cols = ['first_seen','last_seen', 'reqs_per_sec', 'reqs_per_sec_std', 'total_req', 'reqs_max', 'reqs_min']
index = []
feature_data = []
for ip in flows_ip:
    index += [ip]
    feature_data += generate_features(flows_ip[ip], flows_ts_ip[ip])

  
# Create the pandas DataFrame
df = pd.DataFrame(feature_data, columns=cols, index=index)
df
# Out:
#                first_seen     last_seen  reqs_per_sec  reqs_per_sec_std  \
# 102.0.0.4    1.679325e+09  1.679331e+09      3.631068          5.958994
# 172.20.0.10  1.679325e+09  1.679332e+09     84.139130         51.373228
# 172.20.0.11  1.679325e+09  1.679332e+09    395.478261        403.387201
# 172.20.0.12  1.679325e+09  1.679332e+09     72.834783        110.775570
# 102.0.0.7    1.679325e+09  1.679331e+09      5.019608         15.370655
# 102.0.0.6    1.679325e+09  1.679331e+09      3.262136          5.306232
# 102.0.0.9    1.679325e+09  1.679331e+09      3.843137          8.682228
# 102.0.0.8    1.679325e+09  1.679331e+09      4.000000         10.182338
# 102.0.0.5    1.679325e+09  1.679331e+09      3.524752          5.967569
# 102.0.0.10   1.679325e+09  1.679331e+09      2.941176          3.229884
# 102.0.0.12   1.679325e+09  1.679331e+09      4.980392         16.635272
# 102.0.0.11   1.679325e+09  1.679328e+09      3.428571          4.379235
# 102.0.0.2    1.679325e+09  1.679328e+09      8.279070         18.192523
# 102.0.0.18   1.679325e+09  1.679331e+09      3.764706         10.677242
# 102.0.0.17   1.679325e+09  1.679331e+09      3.882353          8.809642
# 102.0.0.13   1.679325e+09  1.679331e+09      3.882353          9.965578
# 102.0.0.22   1.679325e+09  1.679332e+09      5.403509         18.988454
# 102.0.0.21   1.679325e+09  1.679331e+09      3.339806          5.316555
# 102.0.0.24   1.679325e+09  1.679331e+09      3.029126          4.218206
# 102.0.0.25   1.679325e+09  1.679331e+09      2.980392          3.266937
# 102.0.0.15   1.679325e+09  1.679327e+09      4.833333          6.875708
# 102.0.0.23   1.679325e+09  1.679331e+09      3.067961          3.462013
# 102.0.0.19   1.679325e+09  1.679331e+09      3.689320          7.775060
# 102.0.0.3    1.679325e+09  1.679331e+09      3.647059          7.942425
# 102.0.0.16   1.679325e+09  1.679331e+09      3.176471          5.260373
# 102.0.0.26   1.679325e+09  1.679331e+09      2.980392          3.027859
# 102.0.0.14   1.679325e+09  1.679331e+09      3.247525          6.111311
# 102.0.0.20   1.679325e+09  1.679331e+09      3.643564          9.505350
#
#              total_req  reqs_max  reqs_min
# 102.0.0.4          374        42         0
# 172.20.0.10       9676       350         0
# 172.20.0.11      45480      3300         0
# 172.20.0.12       8376       976         0
# 102.0.0.7          512       136         0
# 102.0.0.6          336        52         0
# 102.0.0.9          392        80         0
# 102.0.0.8          404       100         0
# 102.0.0.5          356        52         0
# 102.0.0.10         300        28         0
# 102.0.0.12         508       144         0
# 102.0.0.11         144        28         0
# 102.0.0.2          356        80         0
# 102.0.0.18         384       108         0
# 102.0.0.17         396        64         0
# 102.0.0.13         396       100         0
# 102.0.0.22         616       152         0
# 102.0.0.21         344        40         0
# 102.0.0.24         312        40         0
# 102.0.0.25         304        28         0
# 102.0.0.15         116        28         0
# 102.0.0.23         316        28         0
# 102.0.0.19         380        72         0
# 102.0.0.3          372        76         0
# 102.0.0.16         324        52         0
# 102.0.0.26         304        20         0
# 102.0.0.14         328        60         0
# 102.0.0.20         368        96         0

# %%
normalized_df=(df-df.min())/(df.max()-df.min())
normalized_df = normalized_df.fillna(0)
normalized_df
# Out:
#              first_seen  last_seen  reqs_per_sec  reqs_per_sec_std  total_req  \
# 102.0.0.4      0.000000   0.864429      0.001758          0.007321   0.005687
# 172.20.0.10    0.000011   0.999982      0.206854          0.120755   0.210740
# 172.20.0.11    0.001107   1.000000      1.000000          1.000000   1.000000
# 172.20.0.12    0.002111   1.000000      0.178056          0.269128   0.182083
# 102.0.0.7      0.063858   0.860332      0.005295          0.030829   0.008729
# 102.0.0.6      0.084653   0.867041      0.000818          0.005691   0.004850
# 102.0.0.9      0.107456   0.862100      0.002298          0.014123   0.006084
# 102.0.0.8      0.178245   0.861206      0.002697          0.017870   0.006349
# 102.0.0.5      0.180684   0.862624      0.001487          0.007343   0.005291
# 102.0.0.10     0.189164   0.865641      0.000000          0.000505   0.004056
# 102.0.0.12     0.253755   0.866585      0.005195          0.033988   0.008641
# 102.0.0.11     0.405979   0.201478      0.001242          0.003375   0.000617
# 102.0.0.2      0.411816   0.201777      0.013598          0.037878   0.005291
# 102.0.0.18     0.480641   0.873331      0.002098          0.019106   0.005908
# 102.0.0.17     0.483619   0.864943      0.002398          0.014441   0.006172
# 102.0.0.13     0.510534   0.863724      0.002398          0.017329   0.006172
# 102.0.0.22     0.561378   1.000000      0.006273          0.039866   0.011022
# 102.0.0.21     0.582402   0.876626      0.001016          0.005717   0.005026
# 102.0.0.24     0.644647   0.874862      0.000224          0.002973   0.004321
# 102.0.0.25     0.666806   0.873488      0.000100          0.000597   0.004144
# 102.0.0.15     0.680007   0.000000      0.004820          0.009611   0.000000
# 102.0.0.23     0.692819   0.874181      0.000323          0.001084   0.004409
# 102.0.0.19     0.700641   0.875691      0.001906          0.011857   0.005820
# 102.0.0.3      0.755293   0.865633      0.001798          0.012275   0.005643
# 102.0.0.16     0.904782   0.875073      0.000599          0.005576   0.004585
# 102.0.0.26     0.921309   0.879164      0.000100          0.000000   0.004144
# 102.0.0.14     0.948469   0.873039      0.000780          0.007702   0.004673
# 102.0.0.20     1.000000   0.871478      0.001789          0.016179   0.005555
#
#              reqs_max  reqs_min
# 102.0.0.4    0.006707       0.0
# 172.20.0.10  0.100610       0.0
# 172.20.0.11  1.000000       0.0
# 172.20.0.12  0.291463       0.0
# 102.0.0.7    0.035366       0.0
# 102.0.0.6    0.009756       0.0
# 102.0.0.9    0.018293       0.0
# 102.0.0.8    0.024390       0.0
# 102.0.0.5    0.009756       0.0
# 102.0.0.10   0.002439       0.0
# 102.0.0.12   0.037805       0.0
# 102.0.0.11   0.002439       0.0
# 102.0.0.2    0.018293       0.0
# 102.0.0.18   0.026829       0.0
# 102.0.0.17   0.013415       0.0
# 102.0.0.13   0.024390       0.0
# 102.0.0.22   0.040244       0.0
# 102.0.0.21   0.006098       0.0
# 102.0.0.24   0.006098       0.0
# 102.0.0.25   0.002439       0.0
# 102.0.0.15   0.002439       0.0
# 102.0.0.23   0.002439       0.0
# 102.0.0.19   0.015854       0.0
# 102.0.0.3    0.017073       0.0
# 102.0.0.16   0.009756       0.0
# 102.0.0.26   0.000000       0.0
# 102.0.0.14   0.012195       0.0
# 102.0.0.20   0.023171       0.0

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
normalized_df['cluster'] = kmeans.fit_predict(normalized_df)# get centroids

plt.scatter(normalized_df.first_seen, normalized_df.total_req, c=normalized_df.cluster, alpha = 1, s=10)
# Out:
# /home/taylor/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Cluster and viz dns
# !pip install umap-learn numpy numba
# Dimension reduction and clustering libraries
#import umap.umap_ as umap
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: umap-learn in /home/taylor/.local/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: numpy in /home/taylor/.local/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: numba in /home/taylor/.local/lib/python3.10/site-packages (0.56.4)
# Requirement already satisfied: scipy>=1.0 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (0.5.8)
# Requirement already satisfied: tqdm in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (4.64.1)
# Requirement already satisfied: scikit-learn>=0.22 in /home/taylor/.local/lib/python3.10/site-packages (from umap-learn) (1.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/taylor/.local/lib/python3.10/site-packages (from numba) (0.39.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba) (59.6.0)
# Requirement already satisfied: joblib>=0.11 in /home/taylor/.local/lib/python3.10/site-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)

# %%
#normalized_df=(df-df.min())/(df.max()-df.min())
# standard_embedding = umap.UMAP(random_state=42).fit_transform(normalized_df)
# plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=normalized_df.cluster, s=10, cmap='Spectral');

# %%
# Cluster who this
Server_scope
# Out:
# ['data/argus/csv/myMarkovServer0-101.0.0.10.csv',
#  'data/csv/myMarkovServer0-101.0.0.10.csv']

# %%
def hex_col_to_str(df, col):
    df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))

# %%
# Cluster Server resources
## Create ts for each resource
resource_df = format_time_col(scope_to_df(pcap_only(Server_scope)), 'frame.time')
resource_df['frame.time'] = resource_df['frame.time'].apply(lambda x: x+Shadow_offset)
resource_df_filtered = resource_df[(resource_df['http.request'].notna())]
hex_col_to_str(resource_df_filtered, 'tcp.payload')
resource_df_filtered['resource'] = resource_df_filtered['tcp.payload_str'].apply(lambda x: x.split(' ')[1])
resource_df_filtered
# Out:
# /tmp/ipykernel_18483/2636449078.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col + "_str"] = df[col].apply(lambda x: bytearray.fromhex(x).decode("utf-8"))
# /tmp/ipykernel_18483/4127982458.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resource_df_filtered['resource'] = resource_df_filtered['tcp.payload_str'].apply(lambda x: x.split(' ')[1])
#       frame.number                 frame.time          ip.src      ip.dst  \
# 6                7 2023-03-20 15:12:58.709103  178.165.72.177  101.0.0.10
# 10              11 2023-03-20 15:12:58.738333   104.244.76.39  101.0.0.10
# 26              27 2023-03-20 15:12:59.324435  178.165.72.177  101.0.0.10
# 30              31 2023-03-20 15:12:59.391305   104.244.76.39  101.0.0.10
# 46              47 2023-03-20 15:12:59.944767  178.165.72.177  101.0.0.10
# ...            ...                        ...             ...         ...
# 6554          6555 2023-03-20 15:16:58.690279   104.244.76.39  101.0.0.10
# 6564          6565 2023-03-20 15:16:59.690279   104.244.76.39  101.0.0.10
# 6574          6575 2023-03-20 15:17:02.635171   104.244.76.39  101.0.0.10
# 6584          6585 2023-03-20 15:17:03.635171   104.244.76.39  101.0.0.10
# 6594          6595 2023-03-20 15:17:04.690279   104.244.76.39  101.0.0.10
#
#       ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
# 6            6        200     200            1            0          NaN  ...
# 10           6        200     200            1            0          NaN  ...
# 26           6        200     200            1            0          NaN  ...
# 30           6        200     200            1            0          NaN  ...
# 46           6        200     200            1            0          NaN  ...
# ...        ...        ...     ...          ...          ...          ...  ...
# 6554         6        200     200            1            0          NaN  ...
# 6564         6        200     200            1            0          NaN  ...
# 6574         6        200     200            1            0          NaN  ...
# 6584         6        200     200            1            0          NaN  ...
# 6594         6        200     200            1            0          NaN  ...
#
#       dtls.handshake.extensions_key_share_client_length  http.request  \
# 6                                                   NaN           1.0
# 10                                                  NaN           1.0
# 26                                                  NaN           1.0
# 30                                                  NaN           1.0
# 46                                                  NaN           1.0
# ...                                                 ...           ...
# 6554                                                NaN           1.0
# 6564                                                NaN           1.0
# 6574                                                NaN           1.0
# 6584                                                NaN           1.0
# 6594                                                NaN           1.0
#
#       udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
# 6          NaN             0.307666          0.197256           0.307666
# 10         NaN             0.336896          0.029230           0.327486
# 26         NaN             0.922998          0.158616           0.307666
# 30         NaN             0.989868          0.066870           0.326486
# 46         NaN             1.543330          0.125976           0.312666
# ...        ...                  ...               ...                ...
# 6554       NaN           240.288842          0.194116           0.295116
# 6564       NaN           241.288842          0.194116           0.295116
# 6574       NaN           244.233734          0.157378           0.258378
# 6584       NaN           245.233734          0.157378           0.258378
# 6594       NaN           246.288842          0.194116           0.295116
#
#       tcp.time_delta                                        tcp.payload  \
# 6           0.206666  474554202f7265736f75726365302e68746d6c20485454...
# 10          0.226486  474554202f7265736f75726365312e68746d6c20485454...
# 26          0.206666  474554202f7265736f75726365302e68746d6c20485454...
# 30          0.225486  474554202f7265736f75726365312e68746d6c20485454...
# 46          0.211666  474554202f7265736f75726365302e68746d6c20485454...
# ...              ...                                                ...
# 6554        0.194116  474554202f7265736f75726365302e68746d6c20485454...
# 6564        0.194116  474554202f7265736f75726365302e68746d6c20485454...
# 6574        0.157378  474554202f7265736f75726365302e68746d6c20485454...
# 6584        0.157378  474554202f7265736f75726365302e68746d6c20485454...
# 6594        0.194116  474554202f7265736f75726365302e68746d6c20485454...
#
#                                         tcp.payload_str         resource
# 6     GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 10    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
# 26    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 30    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
# 46    GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# ...                                                 ...              ...
# 6554  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6564  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6574  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6584  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
# 6594  GET /resource0.html HTTP/1.1\r\nHost: 101.0.0....  /resource0.html
#
# [656 rows x 60 columns]

# %%
resources = resource_df_filtered['resource'].unique()
flows_re = {}
flows_ts_re = {}
for resource in resources:
    flows_re[resource] = resource_df_filtered[(resource_df_filtered['resource'] == resource)]
    flows_ts_re[resource] = df_to_ts(flows_re[resource].copy()).set_index('frame.time')
# Out:
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()
# /tmp/ipykernel_18483/2059534349.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   return df.set_index('frame.time').resample('T').sum().dropna().reset_index()

# %%
flows_re
# Out:
# {'/resource0.html':       frame.number                 frame.time          ip.src      ip.dst  \
#  6                7 2023-03-20 15:12:58.709103  178.165.72.177  101.0.0.10
#  26              27 2023-03-20 15:12:59.324435  178.165.72.177  101.0.0.10
#  46              47 2023-03-20 15:12:59.944767  178.165.72.177  101.0.0.10
#  69              70 2023-03-20 15:13:00.560099  178.165.72.177  101.0.0.10
#  73              74 2023-03-20 15:13:00.645171   104.244.76.39  101.0.0.10
#  ...            ...                        ...             ...         ...
#  6554          6555 2023-03-20 15:16:58.690279   104.244.76.39  101.0.0.10
#  6564          6565 2023-03-20 15:16:59.690279   104.244.76.39  101.0.0.10
#  6574          6575 2023-03-20 15:17:02.635171   104.244.76.39  101.0.0.10
#  6584          6585 2023-03-20 15:17:03.635171   104.244.76.39  101.0.0.10
#  6594          6595 2023-03-20 15:17:04.690279   104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  6            6        200     200            1            0          NaN  ...
#  26           6        200     200            1            0          NaN  ...
#  46           6        200     200            1            0          NaN  ...
#  69           6        200     200            1            0          NaN  ...
#  73           6        200     200            1            0          NaN  ...
#  5497          5498 2023-03-20 15:14:44.635171  104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  10           6        200     200            1            0          NaN  ...
#  30           6        200     200            1            0          NaN  ...
#  50           6        200     200            1            0          NaN  ...
#  80           6        200     200            1            0          NaN  ...
#  103          6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  4647         6        200     200            1            0          NaN  ...
#  4760         6        200     200            1            0          NaN  ...
#  4791         6        200     200            1            0          NaN  ...
#  4897         6        200     200            1            0          NaN  ...
#  5497         6        200     200            1            0          NaN  ...
#
#        dtls.handshake.extensions_key_share_client_length  http.request  \
#  10                                                  NaN           1.0
#  30                                                  NaN           1.0
#  50                                                  NaN           1.0
#  80                                                  NaN           1.0
#  103                                                 NaN           1.0
#  ...                                                 ...           ...
#  4647                                                NaN           1.0
#  4760                                                NaN           1.0
#  4791                                                NaN           1.0
#  4897                                                NaN           1.0
#  5497                                                NaN           1.0
#
#        udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
#  10         NaN             0.336896          0.029230           0.327486
#  30         NaN             0.989868          0.066870           0.326486
#  50         NaN             1.642840          0.099510           0.326486
#  80         NaN             2.296812          0.038150           0.326486
#  103        NaN             2.949784          0.075790           0.326486
#  ...        ...                  ...               ...                ...
#  4647       NaN            86.335896          0.062768           0.326486
#  4760       NaN            87.645840          0.052728           0.326486
#  4791       NaN            88.310812          0.043566           0.332486
#  4897       NaN            90.335897          0.002162           0.326486
#  5497       NaN           106.233734          0.148377           0.258378
#
#        tcp.time_delta                                        tcp.payload  \
#  10          0.226486  474554202f7265736f75726365312e68746d6c20485454...
#  30          0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  50          0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  80          0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  103         0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  ...              ...                                                ...
#  4647        0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  4760        0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  4791        0.231486  474554202f7265736f75726365312e68746d6c20485454...
#  4897        0.225486  474554202f7265736f75726365312e68746d6c20485454...
#  5497        0.157378  474554202f7265736f75726365312e68746d6c20485454...
#
#                                          tcp.payload_str         resource
#  10    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  30    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  50    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  80    GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  103   GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  ...                                                 ...              ...
#  4647  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  4760  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  4791  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  4897  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#  5497  GET /resource1.html HTTP/1.1\r\nHost: 101.0.0....  /resource1.html
#
#  [134 rows x 60 columns],
#  '/resource2.html':       frame.number                 frame.time          ip.src      ip.dst  \
#  773            774 2023-03-20 15:13:16.697809  178.165.72.177  101.0.0.10
#  812            813 2023-03-20 15:13:17.286749  178.165.72.177  101.0.0.10
#  865            866 2023-03-20 15:13:17.873689  178.165.72.177  101.0.0.10
#  909            910 2023-03-20 15:13:18.693810  178.165.72.177  101.0.0.10
#  960            961 2023-03-20 15:13:19.309750  178.165.72.177  101.0.0.10
#  ...            ...                        ...             ...         ...
GET /resource2.html HTTP/1.1\r\nHost: 101.0.0....  /resource2.html
#
#  [130 rows x 60 columns],
#  '/resource3.html':       frame.number                 frame.time         ip.src      ip.dst  \
#  1702          1703 2023-03-20 15:13:37.635171  104.244.76.39  101.0.0.10
#  1710          1711 2023-03-20 15:13:37.690278  104.244.76.39  101.0.0.10
#  1755          1756 2023-03-20 15:13:38.644172  104.244.76.39  101.0.0.10
#  1759          1760 2023-03-20 15:13:38.690278  104.244.76.39  101.0.0.10
#  1799          1800 2023-03-20 15:13:39.160928  104.244.76.39  101.0.0.10
#  ...            ...                        ...            ...         ...
#  5737          5738 2023-03-20 15:15:04.635171  104.244.76.39  101.0.0.10
#  5741          5742 2023-03-20 15:15:04.644172  104.244.76.39  101.0.0.10
#  5754          5755 2023-03-20 15:15:05.160928  104.244.76.39  101.0.0.10
#  5764          5765 2023-03-20 15:15:05.677684  104.244.76.39  101.0.0.10
#  6011          6012 2023-03-20 15:15:37.635171  104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  1702         6        200     200            1            0          NaN  ...
#  1710         6        200     200            1            0          NaN  ...
#  1755         6        200     200            1            0          NaN  ...
#  1759         6        200     200            1            0          NaN  ...
#  1799         6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  5737         6        200     200            1            0          NaN  ...
#  5741         6        200     200            1            0          NaN  ...
#  5754         6        200     200            1            0          NaN  ...
#  5764         6        200     200            1            0          NaN  ...
#  6011         6        200     200            1            0          NaN  ...
#
#        dtls.handshake.extensions_key_share_client_length  http.request  \
#  1702                                                NaN           1.0
#  1710                                                NaN           1.0
#  1755                                                NaN           1.0
#  1759                                                NaN           1.0
#  1799                                                NaN           1.0
#  ...                                                 ...           ...
#  5737                                                NaN           1.0
#  5741                                                NaN           1.0
#  5754                                                NaN           1.0
#  5764                                                NaN           1.0
#  6011                                                NaN           1.0
#
#        udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
#  1702       NaN            39.233734          0.132734           0.258378
#  1710       NaN            39.288841          0.046106           0.295116
#  1755       NaN            40.242735          0.116866           0.258378
#  1759       NaN            40.288841          0.046106           0.295116
#  1799       NaN            40.759491          0.073534           0.258378
#  ...        ...                  ...               ...                ...
#  5737       NaN           126.233734          0.148377           0.258378
#  5741       NaN           126.242735          0.009001           0.258378
#  5754       NaN           126.759491          0.157378           0.258378
#  5764       NaN           127.276247          0.157378           0.258378
#  6011       NaN           159.233734          0.000000           0.258378
#
#        tcp.time_delta                                        tcp.payload  \
#  1702        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  1710        0.194116  474554202f7265736f75726365332e68746d6c20485454...
#  1755        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  1759        0.194116  474554202f7265736f75726365332e68746d6c20485454...
#  1799        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  ...              ...                                                ...
#  5737        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  5741        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  5754        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  5764        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#  6011        0.157378  474554202f7265736f75726365332e68746d6c20485454...
#
#                                          tcp.payload_str         resource
#  1702  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1710  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1755  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1759  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  1799  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  ...                                                 ...              ...
#  5737  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  5741  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  5754  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  5764  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#  6011  GET /resource3.html HTTP/1.1\r\nHost: 101.0.0....  /resource3.html
#
#  [128 rows x 60 columns],
#  '/resource4.html':       frame.number                 frame.time         ip.src      ip.dst  \
#  1975          1976 2023-03-20 15:13:44.635171  104.244.76.39  101.0.0.10
#  2080          2081 2023-03-20 15:13:46.644172  104.244.76.39  101.0.0.10
#  2103          2104 2023-03-20 15:13:47.163928  104.244.76.39  101.0.0.10
#  2130          2131 2023-03-20 15:13:47.681684  104.244.76.39  101.0.0.10
#  2160          2161 2023-03-20 15:13:48.198440  104.244.76.39  101.0.0.10
#  ...            ...                        ...            ...         ...
#  5964          5965 2023-03-20 15:15:31.668683  104.244.76.39  101.0.0.10
#  5974          5975 2023-03-20 15:15:32.635171  104.244.76.39  101.0.0.10
#  5994          5995 2023-03-20 15:15:36.635172  104.244.76.39  101.0.0.10
#  6010          6011 2023-03-20 15:15:37.635171  104.244.76.39  101.0.0.10
#  6044          6045 2023-03-20 15:15:43.635172  104.244.76.39  101.0.0.10
#
#        ip.proto  frame.len  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  ...  \
#  1975         6        200     200            1            0          NaN  ...
#  2080         6        200     200            1            0          NaN  ...
#  2103         6        200     200            1            0          NaN  ...
#  2130         6        200     200            1            0          NaN  ...
#  2160         6        200     200            1            0          NaN  ...
#  ...        ...        ...     ...          ...          ...          ...  ...
#  5964         6        200     200            1            0          NaN  ...
#  5974         6        200     200            1            0          NaN  ...
#  5994         6        200     200            1            0          NaN  ...
#  6010         6        200     200            1            0          NaN  ...
#  6044         6        200     200            1            0          NaN  ...
#
#        dtls.handshake.extensions_key_share_client_length  http.request  \
#  1975                                                NaN           1.0
#  2080                                                NaN           1.0
#  2103                                                NaN           1.0
#  2130                                                NaN           1.0
#  2160                                                NaN           1.0
#  ...                                                 ...           ...
#  5964                                                NaN           1.0
#  5974                                                NaN           1.0
#  5994                                                NaN           1.0
#  6010                                                NaN           1.0
#  6044                                                NaN           1.0
#
#        udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
#  1975       NaN            46.233734          0.139009           0.258378
#  2080       NaN            48.242735          0.009001           0.258378
#  2103       NaN            48.762491          0.157378           0.258378
#  2130       NaN            49.280247          0.046513           0.259378
#  2160       NaN            49.797003          0.046513           0.258378
#  ...        ...                  ...               ...                ...
#  5964       NaN           153.267246          0.157378           0.258378
#  5974       NaN           154.233734          0.157378           0.258378
#  5994       NaN           158.233735          0.157378           0.258378
#  6010       NaN           159.233734          0.132734           0.258378
#  6044       NaN           165.233735          0.157378           0.258378
#
#        tcp.time_delta                                        tcp.payload  \
#  1975        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  2080        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  2103        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  2130        0.158378  474554202f7265736f75726365342e68746d6c20485454...
#  2160        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  ...              ...                                                ...
#  5964        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  5974        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  5994        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  6010        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#  6044        0.157378  474554202f7265736f75726365342e68746d6c20485454...
#
#                                          tcp.payload_str         resource
#  1975  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2080  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2103  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2130  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  2160  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  ...                                                 ...              ...
#  5964  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  5974  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  5994  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  6010  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#  6044  GET /resource4.html HTTP/1.1\r\nHost: 101.0.0....  /resource4.html
#
#  [119 rows x 60 columns]}

# %%
import numpy as np
def generate_features_resource(df, flow):
    features = []
    # 'first_seen'
    #features += [float(df['frame.time'].min().timestamp())]
    features += [df['frame.time'].min()]
    # 'last_seen'
    #features += [float(df['frame.time'].max().timestamp())]
    features += [df['frame.time'].max()]
    # 'reqs_per_sec'
    features += [flow['count'].mean()]
    # 'reqs_per_sec_std'
    val = flow['count'].std()
    features += [0 if np.isnan(val) else val]
    # 'total_req'
    features += [len(df)]
    # 'reqs_max'
    features += [flow['count'].max()]
    # 'reqs_min'
    features += [flow['count'].min()]
    return [features]
## Get flow features
cols = ['first_seen','last_seen', 'reqs_per_sec', 'reqs_per_sec_std', 'total_req', 'reqs_max', 'reqs_min']
index = []
feature_data = []
for ip in flows_re:
    index += [ip]
    feature_data += generate_features_resource(flows_re[ip], flows_ts_re[ip])

  
# Create the pandas DataFrame
df_resource = pd.DataFrame(feature_data, columns=cols, index=index)
df_resource
# Out:
#                                 first_seen                  last_seen  \
# /resource0.html 2023-03-20 15:12:58.709103 2023-03-20 15:17:04.690279
# /resource1.html 2023-03-20 15:12:58.738333 2023-03-20 15:14:44.635171
# /resource2.html 2023-03-20 15:13:16.697809 2023-03-20 15:15:39.700277
# /resource3.html 2023-03-20 15:13:37.635171 2023-03-20 15:15:37.635171
# /resource4.html 2023-03-20 15:13:44.635171 2023-03-20 15:15:43.635172
#
#                  reqs_per_sec  reqs_per_sec_std  total_req  reqs_max  reqs_min
# /resource0.html     24.166667         23.861405        145        64         3
# /resource1.html     44.666667         47.595518        134        96         2
# /resource2.html     43.333333         43.096790        130        88         2
# /resource3.html     42.666667         38.527047        128        82         5
# /resource4.html     39.666667         22.941956        119        66        24

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

for f in flows_ts_re:
    flows_ts_re[f]['count'].plot(label=f)
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
  
# adding legend to the curve
plt.legend()

# %%
# Link
# Which group has what signal
groups = normalized_df['cluster'].unique()
dtypes = list(flows_ts_ip.values())[0].dtypes.to_dict()
cols = list(list(flows_ts_ip.values())[0].columns)
sum_ts = {}
for group in groups:
    sum_ts[group] = pd.DataFrame(columns=cols)
    sum_ts[group].astype(dtypes)
    #sum_ts[group].set_index('frame.time')
for ip in normalized_df.index.tolist():
    s = flows_ts_ip[ip].add(sum_ts[normalized_df.loc[ip]['cluster']], fill_value=0)
    sum_ts[normalized_df.loc[ip]['cluster']] = s

# %%
# normalize ts

# %%
# resource_and_groups = sum_ts + flows_ts_re
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.

limit = 10

for f in flows_ts_re:
    flows_ts_re[f]['count'].head(limit).plot(label=f)
for f in sum_ts:
    #print(min(sum_ts[f].index.values)  - (10 * 1000000000))
    sum_ts[f]['count'].div(32).head(limit).plot(label=f)
    
  
plt.title('Requests per second')
  
# adding Label to the x-axis
plt.xlabel('Time')
  
# adding legend to the curve
plt.legend()

# %%
# Find mathing groups for resources
# !pip install pyts

from pyts.metrics import dtw, itakura_parallelogram, sakoe_chiba_band
from pyts.metrics.dtw import (cost_matrix, accumulated_cost_matrix,
                              _return_path, _blurred_path_region)

def compare_ts(ts1, ts2):
    dtw_classic, path_classic = dtw(ts1, ts2, dist='square',
                                method='classic', return_path=True)
    return dtw_classic

def normalize_ts(ts):
    ts=(ts-ts.min())/(ts.max()-ts.min())
    return ts.fillna(0)

def compare_ts_reshape(ts1, ts2):
    ts1_norm = ts1.copy(deep=True)
    ts2_norm = ts2.copy(deep=True)
    
    buffer_room = 10 # in seconds
    
    # lock to same range with buffer room on each side to account for network (or PPT) delay
    start = min(ts1.index.values)
    end = max(ts1.index.values) + (buffer_room * 1000000000)
    #print("start: " + str(max_start))
    #print("end: " + str(min_end))
    #print(end - start)
    
    ts1_norm = ts1_norm[start:end]
    ts2_norm = ts2_norm[start:end]
    print(len(ts2_norm))
    
    # detect if no overlap
    if len(ts1_norm) < 2 or len(ts2_norm) < 2:
        return float("inf")
    
    # Normalize peaks?
    ts1_norm = normalize_ts(ts1_norm)
    ts2_norm = normalize_ts(ts2_norm)

    return compare_ts(ts1_norm, ts2_norm)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyts in /home/taylor/.local/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.2.1)
# Requirement already satisfied: scipy>=1.3.0 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.10.1)
# Requirement already satisfied: numba>=0.48.0 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (0.56.4)
# Requirement already satisfied: numpy>=1.17.5 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.23.5)
# Requirement already satisfied: joblib>=0.12 in /home/taylor/.local/lib/python3.10/site-packages (from pyts) (1.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/taylor/.local/lib/python3.10/site-packages (from numba>=0.48.0->pyts) (0.39.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba>=0.48.0->pyts) (59.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taylor/.local/lib/python3.10/site-packages (from scikit-learn>=0.22.1->pyts) (3.1.0)

# %%
answer = {'/resource0.html': 0, '/resource1.html': 1, '/resource2.html': 2, '/resource3.html': 3, '/resource4.html': 4, '/': -1}
num_correct = 0.0
for f in flows_ts_re:
    print(f)
    best_group = -1
    best_sim = -1
    for c in sum_ts:
        if len(sum_ts[c]['count']) < 2:
            print("\tGroup " + str(c) + " is too short. Skipping")
            continue
        sim = compare_ts_reshape(flows_ts_re[f]['count'], sum_ts[c]['count'].div(1))
        print("\tGroup " + str(c) + "\t\tSim:" + str(sim))
        if best_group == -1 or best_sim > sim:
            best_group = c
            best_sim = sim
    print("\n\tBest match is group " + str(best_group) + " with sim " + str(best_sim))
    if answer[f] == best_group:
        print('Correct!\n\n')
        num_correct += 1
print(str(num_correct/len(answer) *100) + "% Correct")
# Out:
# /resource0.html
# 4
# 	Group 1		Sim:0.5130614334991649
# 4
# 	Group 2		Sim:0.4896374410586126
# 3
# 	Group 3		Sim:1.0475267673364757
# 3
# 	Group 4		Sim:1.2256886126498157
# 2
# 	Group 0		Sim:1.2196324689479257
#
# 	Best match is group 2 with sim 0.4896374410586126
# /resource1.html
# 1
# 	Group 1		Sim:inf
# 1
# 	Group 2		Sim:inf
# 0
# 	Group 3		Sim:inf
# 0
# 	Group 4		Sim:inf
# 0
# 	Group 0		Sim:inf
#
# 	Best match is group 1 with sim inf
# Correct!
#
#
# /resource2.html
# 2
# 	Group 1		Sim:1.093270630097038
# 2
# 	Group 2		Sim:1.093270630097038
# 1
# 	Group 3		Sim:inf
# 1
# 	Group 4		Sim:inf
# 0
# 	Group 0		Sim:inf
#
# 	Best match is group 1 with sim 1.093270630097038
# /resource3.html
# 2
# 	Group 1		Sim:1.103896103896104
# 2
# 	Group 2		Sim:1.103896103896104
# 1
# 	Group 3		Sim:inf
# 1
# 	Group 4		Sim:inf
# 0
# 	Group 0		Sim:inf
#
# 	Best match is group 1 with sim 1.103896103896104
# /resource4.html
# 2
# 	Group 1		Sim:1.0070612372646002
# 2
# 	Group 2		Sim:1.0070612372646002
# 1
# 	Group 3		Sim:inf
# 1
# 	Group 4		Sim:inf
# 0
# 	Group 0		Sim:inf
#
# 	Best match is group 1 with sim 1.0070612372646002
# 16.666666666666664% Correct
